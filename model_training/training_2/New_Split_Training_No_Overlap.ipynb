# %%
# Cell 1: Import required libraries
import os
import cv2
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision.transforms as transforms
import timm

from sklearn.metrics import roc_auc_score
from scipy.ndimage import gaussian_filter, map_coordinates
import random

import time

from sklearn.preprocessing import MultiLabelBinarizer

# %%
# Cell 2: Define custom augmentation transforms

# CLAHE Transform for grayscale images
class CLAHETransform:
    def __init__(self, clipLimit=2.0, tileGridSize=(8, 8)):
        self.clahe = cv2.createCLAHE(clipLimit=clipLimit, tileGridSize=tileGridSize)

    def __call__(self, img):
        img_np = np.array(img)
        # For grayscale images, apply CLAHE directly
        img_np = self.clahe.apply(img_np)
        return Image.fromarray(img_np)

# Gamma Correction Transform
class GammaCorrectionTransform:
    def __init__(self, gamma=1.0):
        self.gamma = gamma

    def __call__(self, img):
        img_np = np.array(img).astype(np.float32) / 255.0
        corrected = np.power(img_np, self.gamma)
        corrected = np.clip(corrected * 255, 0, 255).astype(np.uint8)
        return Image.fromarray(corrected)

# Elastic Deformation Transform
class ElasticTransform:
    def __init__(self, alpha=34, sigma=4, random_state=None):
        self.alpha = alpha
        self.sigma = sigma
        self.random_state = random_state if random_state is not None else np.random.RandomState(None)

    def __call__(self, img):
        img_np = np.array(img)
        shape = img_np.shape[:2]
        
        dx = gaussian_filter((self.random_state.rand(*shape) * 2 - 1), self.sigma, mode="constant", cval=0) * self.alpha
        dy = gaussian_filter((self.random_state.rand(*shape) * 2 - 1), self.sigma, mode="constant", cval=0) * self.alpha
        
        x, y = np.meshgrid(np.arange(shape[1]), np.arange(shape[0]))
        indices = np.reshape(y+dy, (-1, 1)), np.reshape(x+dx, (-1, 1))
        
        if img_np.ndim == 3:
            channels = []
            for i in range(img_np.shape[2]):
                channel = map_coordinates(img_np[..., i], indices, order=1, mode='reflect').reshape(shape)
                channels.append(channel)
            transformed = np.stack(channels, axis=2)
        else:
            transformed = map_coordinates(img_np, indices, order=1, mode='reflect').reshape(shape)
        return Image.fromarray(transformed.astype(np.uint8))

# %%
# Cell 3: Define Focal Loss for multi-label classification
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        """
        Args:
            alpha (float): Balancing factor.
            gamma (float): Focusing parameter.
            reduction (str): Reduction method ('mean', 'sum', or 'none').
        """
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        
    def forward(self, inputs, targets):
        # Compute binary cross entropy loss per element
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer

# Define the 15 classes (14 diseases plus "No Finding")
CLASSES = [
    "No Finding", "Atelectasis", "Cardiomegaly", "Effusion", "Infiltration", 
    "Mass", "Nodule", "Pneumonia", "Pneumothorax", "Consolidation", 
    "Edema", "Emphysema", "Fibrosis", "Pleural_Thickening", "Hernia"
]

# Load CSV data
df = pd.read_csv("/student/csc490_project/shared/labels.csv")

# Process the "Finding Labels" column.
# For "No Finding", this will return ["No Finding"],
# and for multiple findings it splits by '|'.
def process_labels(label_str):
    return label_str.split("|")

df["label_list"] = df["Finding Labels"].apply(process_labels)

# Initialize and apply MultiLabelBinarizer with our defined classes.
mlb = MultiLabelBinarizer(classes=CLASSES)
labels_array = mlb.fit_transform(df["label_list"])

# Save the multi-hot vectors into a new column.
df["labels"] = list(labels_array)

# Get the unique patient IDs from the dataset
unique_patients = df["Patient ID"].unique()

# Shuffle the patient IDs using a fixed random seed for reproducibility
np.random.seed(42)
np.random.shuffle(unique_patients)

# Determine the split index for a 70/30 split (by patient)
split_index = int(0.7 * len(unique_patients))
train_patients = unique_patients[:split_index]
val_patients = unique_patients[split_index:]

# Filter the dataframe based on the patient IDs for each split
train_df = df[df["Patient ID"].isin(train_patients)].reset_index(drop=True)
val_df = df[df["Patient ID"].isin(val_patients)].reset_index(drop=True)

print(f"Training samples: {len(train_df)}, Validation samples: {len(val_df)}")

# Print unique patient counts for each split to verify no overlap
print(f"Unique patients in training: {len(train_df['Patient ID'].unique())}")
print(f"Unique patients in validation: {len(val_df['Patient ID'].unique())}")

# Verify there is no overlap in patient IDs between the splits
overlap_ids = set(train_df["Patient ID"].unique()).intersection(val_df["Patient ID"].unique())
if overlap_ids:
    print("Overlap in Patient IDs found:", overlap_ids)
else:
    print("No overlap in Patient IDs between training and validation sets.")

# Define the dataset class using the precomputed multi-hot labels.
class ChestXrayDataset(Dataset):
    def __init__(self, df, root_dir, transform=None):
        """
        Args:
            df: DataFrame with columns "Image Index" and "labels".
            root_dir: Directory where images are stored.
            transform: Transformations to apply.
        """
        self.df = df
        self.root_dir = root_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        # Load the image in grayscale.
        img_name = os.path.join(self.root_dir, self.df.iloc[idx]["Image Index"])
        image = Image.open(img_name).convert("L")
        
        # Retrieve the multi-hot label vector (length 15).
        labels = np.array(self.df.iloc[idx]["labels"], dtype=np.float32)
        labels = torch.tensor(labels, dtype=torch.float)
        
        if self.transform:
            image = self.transform(image)
        return image, labels
# Out:
# Training samples: 78708, Validation samples: 33412
# Unique patients in training: 21563
# Unique patients in validation: 9242
# No overlap in Patient IDs between training and validation sets.

# %%
# Cell 5: Record split index

# Print dataset sizes
print(f"Total samples: {len(df)}")
print(f"Training samples: {len(train_df)}, Validation samples: {len(val_df)}")
print(f"Split index: {split_index}")

# Print first 5 indices of each split to verify consistency
print("First 5 indices in training set:")
print(train_df.index[:5].tolist())

print("First 5 indices in validation set:")
print(val_df.index[:5].tolist())

# Print first few image filenames in each split
print("First 5 images in training set:")
print(train_df["Image Index"].head().tolist())

print("First 5 images in validation set:")
print(val_df["Image Index"].head().tolist())
# Out:
# Total samples: 112120
# Training samples: 78708, Validation samples: 33412
# Split index: 21563
# First 5 indices in training set:
# [0, 1, 2, 3, 4]
# First 5 indices in validation set:
# [0, 1, 2, 3, 4]
# First 5 images in training set:
# ['00000001_000.png', '00000001_001.png', '00000001_002.png', '00000003_000.png', '00000003_001.png']
# First 5 images in validation set:
# ['00000002_000.png', '00000010_000.png', '00000012_000.png', '00000014_000.png', '00000017_000.png']

# %%
# Cell 6: Define data transforms with selectable augmentation

# Choose augmentation method: 'clahe', 'gamma', 'elastic', or 'none'
augmentation_method = 'none'  # Change this as needed

if augmentation_method == 'clahe':
    aug_transform = CLAHETransform(clipLimit=2.0, tileGridSize=(8, 8))
elif augmentation_method == 'gamma':
    aug_transform = GammaCorrectionTransform(gamma=0.8)  # adjust gamma value as needed
elif augmentation_method == 'elastic':
    aug_transform = ElasticTransform(alpha=34, sigma=4)
else:
    aug_transform = None

# Compose training transforms. The pipeline applies the selected augmentation,
# converts the grayscale image to 3 channels, and performs other random augmentations.
train_transforms_list = []
if aug_transform is not None:
    train_transforms_list.append(aug_transform)
    
train_transforms_list += [
    transforms.Grayscale(num_output_channels=3),  # Convert to 3 channels for the model
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
]

train_transform = transforms.Compose(train_transforms_list)

# Validation transforms: use deterministic preprocessing only
val_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Cell 7: Create DataLoaders for training and validation
train_dataset = ChestXrayDataset(train_df, root_dir="/student/csc490_project/shared/preprocessed_images/preprocessed_images", transform=train_transform)
val_dataset = ChestXrayDataset(val_df, root_dir="/student/csc490_project/shared/preprocessed_images/preprocessed_images", transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)

# %%
# Cell 8: Model List
model_names = ['coatnet_2_rw_224.sw_in12k_ft_in1k', 'convnext_large.fb_in22k', 'densenet121', 'maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k', 'swin_large_patch4_window7_224', 'vgg19.tv_in1k']
num_classes = 15

# %%
# Cell 9: Define the loss function selection
loss_type = 'bce'  # Change to 'focal' to use FocalLoss

if loss_type == 'bce':
    criterion = nn.BCEWithLogitsLoss()
elif loss_type == 'focal':
    criterion = FocalLoss(alpha=1, gamma=2, reduction='mean')
else:
    raise ValueError("Invalid loss_type. Choose 'bce' or 'focal'.")

# %%
# Cell 10: Training loop with validation AUROC evaluation
for model_name in model_names:
    
    model = timm.create_model(model_name, pretrained=True, num_classes=num_classes)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    if model_name == 'convnext_large.fb_in22k':
        num_epochs = 4
    else:
        num_epochs = 7

    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(num_epochs):
        start_time = time.time()
        model.train()
        running_loss = 0.0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * images.size(0)
        
        epoch_loss = running_loss / len(train_dataset)
        epoch_runtime = time.time() - start_time
        print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {epoch_loss:.4f}, Runtime: {epoch_runtime:.2f} seconds")
        
        # Validation evaluation
        model.eval()
        val_loss = 0.0
        all_preds = []
        all_labels = []
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                
                preds = torch.sigmoid(outputs).cpu().numpy()
                all_preds.append(preds)
                all_labels.append(labels.cpu().numpy())
        
        val_loss /= len(val_dataset)
        print(f"Model: {model_name}, Epoch {epoch+1}/{num_epochs}, Validation Loss: {val_loss:.4f}")
        
        all_preds = np.concatenate(all_preds, axis=0)
        all_labels = np.concatenate(all_labels, axis=0)
        
        # Compute AUROC for each class
        auroc_per_class = {}
        for i, class_name in enumerate(CLASSES):  # Iterate with class names directly
            try:
                auroc = roc_auc_score(all_labels[:, i], all_preds[:, i])
            except ValueError:
                auroc = float('nan')
            auroc_per_class[class_name] = auroc  # Store class name instead of index

        overall_auroc = np.nanmean(list(auroc_per_class.values()))

        print("Validation AUROC per class:")
        for class_name, score in auroc_per_class.items():
            print(f"  {class_name}: {score:.4f}")
        if epoch + 1 != num_epochs:
            print(f"Overall AUROC: {overall_auroc:.4f}\n")
        else:
            print(f"Final AUROC: {overall_auroc:.4f}\n")

    model_save_path = f"/student/csc490_project/shared/new_split_models/no_augment_{model_name}_model.pth"
    torch.save(model.state_dict(), model_save_path)
    print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/7, Training Loss: 0.1978, Runtime: 641.89 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 1/7, Validation Loss: 0.1850
# Validation AUROC per class:
#   No Finding: 0.7684
#   Atelectasis: 0.7703
#   Cardiomegaly: 0.8540
#   Effusion: 0.8620
#   Infiltration: 0.6938
#   Mass: 0.7960
#   Nodule: 0.7142
#   Pneumonia: 0.7096
#   Pneumothorax: 0.8351
#   Consolidation: 0.7773
#   Edema: 0.8487
#   Emphysema: 0.8152
#   Fibrosis: 0.7469
#   Pleural_Thickening: 0.7629
#   Hernia: 0.7097
# Overall AUROC: 0.7776
#
# Epoch 2/7, Training Loss: 0.1861, Runtime: 642.13 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 2/7, Validation Loss: 0.1829
# Validation AUROC per class:
#   No Finding: 0.7798
#   Atelectasis: 0.7929
#   Cardiomegaly: 0.8738
#   Effusion: 0.8738
#   Infiltration: 0.7026
#   Mass: 0.8411
#   Nodule: 0.7525
#   Pneumonia: 0.7437
#   Pneumothorax: 0.8602
#   Consolidation: 0.7903
#   Edema: 0.8877
#   Emphysema: 0.8814
#   Fibrosis: 0.7598
#   Pleural_Thickening: 0.7920
#   Hernia: 0.7081
# Overall AUROC: 0.8026
#
# Epoch 3/7, Training Loss: 0.1811, Runtime: 642.53 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 3/7, Validation Loss: 0.1807
# Validation AUROC per class:
#   No Finding: 0.7775
#   Atelectasis: 0.7960
#   Cardiomegaly: 0.8703
#   Effusion: 0.8725
#   Infiltration: 0.7074
#   Mass: 0.8343
#   Nodule: 0.7428
#   Pneumonia: 0.7533
#   Pneumothorax: 0.8575
#   Consolidation: 0.7789
#   Edema: 0.8923
#   Emphysema: 0.9005
#   Fibrosis: 0.7562
#   Pleural_Thickening: 0.7931
#   Hernia: 0.7526
# Overall AUROC: 0.8057
#
# Epoch 4/7, Training Loss: 0.1779, Runtime: 642.51 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 4/7, Validation Loss: 0.1749
# Validation AUROC per class:
#   No Finding: 0.7824
#   Atelectasis: 0.8130
#   Cardiomegaly: 0.8931
#   Effusion: 0.8780
#   Infiltration: 0.7141
#   Mass: 0.8499
#   Nodule: 0.7619
#   Pneumonia: 0.7467
#   Pneumothorax: 0.8769
#   Consolidation: 0.8019
#   Edema: 0.8992
#   Emphysema: 0.9105
#   Fibrosis: 0.7904
#   Pleural_Thickening: 0.7704
#   Hernia: 0.8543
# Overall AUROC: 0.8229
#
# Epoch 5/7, Training Loss: 0.1754, Runtime: 642.76 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 5/7, Validation Loss: 0.1760
# Validation AUROC per class:
#   No Finding: 0.7862
#   Atelectasis: 0.8179
#   Cardiomegaly: 0.8921
#   Effusion: 0.8833
#   Infiltration: 0.7174
#   Mass: 0.8441
#   Nodule: 0.7719
#   Pneumonia: 0.7565
#   Pneumothorax: 0.8747
#   Consolidation: 0.8009
#   Edema: 0.9027
#   Emphysema: 0.9166
#   Fibrosis: 0.7928
#   Pleural_Thickening: 0.7969
#   Hernia: 0.8291
# Overall AUROC: 0.8255
#
# Epoch 6/7, Training Loss: 0.1732, Runtime: 642.84 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 6/7, Validation Loss: 0.1730
# Validation AUROC per class:
#   No Finding: 0.7862
#   Atelectasis: 0.8220
#   Cardiomegaly: 0.8857
#   Effusion: 0.8833
#   Infiltration: 0.7200
#   Mass: 0.8576
#   Nodule: 0.7802
#   Pneumonia: 0.7605
#   Pneumothorax: 0.8694
#   Consolidation: 0.8006
#   Edema: 0.8983
#   Emphysema: 0.9163
#   Fibrosis: 0.8066
#   Pleural_Thickening: 0.8049
#   Hernia: 0.8637
# Overall AUROC: 0.8304
#
# Epoch 7/7, Training Loss: 0.1714, Runtime: 642.88 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 7/7, Validation Loss: 0.1752
# Validation AUROC per class:
#   No Finding: 0.7886
#   Atelectasis: 0.8164
#   Cardiomegaly: 0.8950
#   Effusion: 0.8838
#   Infiltration: 0.7275
#   Mass: 0.8578
#   Nodule: 0.7726
#   Pneumonia: 0.7544
#   Pneumothorax: 0.8808
#   Consolidation: 0.8017
#   Edema: 0.9009
#   Emphysema: 0.9215
#   Fibrosis: 0.8011
#   Pleural_Thickening: 0.8065
#   Hernia: 0.8800
# Final AUROC: 0.8326
#
# Model saved to /student/csc490_project/shared/new_split_models/no_augment_coatnet_2_rw_224.sw_in12k_ft_in1k_model.pth
# Epoch 1/4, Training Loss: 0.1849, Runtime: 1141.37 seconds
# Model: convnext_large.fb_in22k, Epoch 1/4, Validation Loss: 0.1747
# Validation AUROC per class:
#   No Finding: 0.7875
#   Atelectasis: 0.8210
#   Cardiomegaly: 0.8955
#   Effusion: 0.8847
#   Infiltration: 0.7156
#   Mass: 0.8534
#   Nodule: 0.7677
#   Pneumonia: 0.7586
#   Pneumothorax: 0.8728
#   Consolidation: 0.7988
#   Edema: 0.8868
#   Emphysema: 0.9164
#   Fibrosis: 0.8035
#   Pleural_Thickening: 0.8056
#   Hernia: 0.7988
# Overall AUROC: 0.8244
#
# Epoch 2/4, Training Loss: 0.1721, Runtime: 1141.26 seconds
# Model: convnext_large.fb_in22k, Epoch 2/4, Validation Loss: 0.1710
# Validation AUROC per class:
#   No Finding: 0.7925
#   Atelectasis: 0.8320
#   Cardiomegaly: 0.9117
#   Effusion: 0.8905
#   Infiltration: 0.7236
#   Mass: 0.8643
#   Nodule: 0.7743
#   Pneumonia: 0.7745
#   Pneumothorax: 0.8875
#   Consolidation: 0.8054
#   Edema: 0.9035
#   Emphysema: 0.9263
#   Fibrosis: 0.8081
#   Pleural_Thickening: 0.8152
#   Hernia: 0.8763
# Overall AUROC: 0.8390
#
# Epoch 3/4, Training Loss: 0.1642, Runtime: 1141.23 seconds
# Model: convnext_large.fb_in22k, Epoch 3/4, Validation Loss: 0.1728
# Validation AUROC per class:
#   No Finding: 0.7920
#   Atelectasis: 0.8281
#   Cardiomegaly: 0.8967
#   Effusion: 0.8868
#   Infiltration: 0.7283
#   Mass: 0.8545
#   Nodule: 0.7844
#   Pneumonia: 0.7631
#   Pneumothorax: 0.8889
#   Consolidation: 0.8033
#   Edema: 0.8988
#   Emphysema: 0.9240
#   Fibrosis: 0.8227
#   Pleural_Thickening: 0.8125
#   Hernia: 0.8974
# Overall AUROC: 0.8388
#
# Epoch 4/4, Training Loss: 0.1530, Runtime: 1141.07 seconds
# Model: convnext_large.fb_in22k, Epoch 4/4, Validation Loss: 0.1780
# Validation AUROC per class:
#   No Finding: 0.7866
#   Atelectasis: 0.8228
#   Cardiomegaly: 0.8994
#   Effusion: 0.8844
#   Infiltration: 0.7139
#   Mass: 0.8555
#   Nodule: 0.7859
#   Pneumonia: 0.7373
#   Pneumothorax: 0.8680
#   Consolidation: 0.7940
#   Edema: 0.8962
#   Emphysema: 0.9324
#   Fibrosis: 0.8083
#   Pleural_Thickening: 0.8045
#   Hernia: 0.8952
# Final AUROC: 0.8323
#
# Model saved to /student/csc490_project/shared/new_split_models/no_augment_convnext_large.fb_in22k_model.pth
# model.safetensors:   0%|          | 0.00/32.3M [00:00<?, ?B/s]
# Epoch 1/7, Training Loss: 0.1941, Runtime: 159.21 seconds
# Model: densenet121, Epoch 1/7, Validation Loss: 0.1808
# Validation AUROC per class:
#   No Finding: 0.7716
#   Atelectasis: 0.7948
#   Cardiomegaly: 0.8653
#   Effusion: 0.8728
#   Infiltration: 0.6975
#   Mass: 0.8097
#   Nodule: 0.7066
#   Pneumonia: 0.7412
#   Pneumothorax: 0.8597
#   Consolidation: 0.7919
#   Edema: 0.8913
#   Emphysema: 0.8788
#   Fibrosis: 0.7436
#   Pleural_Thickening: 0.7832
#   Hernia: 0.7404
# Overall AUROC: 0.7966
#
# Epoch 2/7, Training Loss: 0.1806, Runtime: 159.53 seconds
# Model: densenet121, Epoch 2/7, Validation Loss: 0.1768
# Validation AUROC per class:
#   No Finding: 0.7807
#   Atelectasis: 0.8098
#   Cardiomegaly: 0.8859
#   Effusion: 0.8747
#   Infiltration: 0.7013
#   Mass: 0.8385
#   Nodule: 0.7455
#   Pneumonia: 0.7441
#   Pneumothorax: 0.8688
#   Consolidation: 0.7882
#   Edema: 0.8916
#   Emphysema: 0.9020
#   Fibrosis: 0.7892
#   Pleural_Thickening: 0.7993
#   Hernia: 0.8271
# Overall AUROC: 0.8165
#
# Epoch 3/7, Training Loss: 0.1761, Runtime: 159.47 seconds
# Model: densenet121, Epoch 3/7, Validation Loss: 0.1772
# Validation AUROC per class:
#   No Finding: 0.7783
#   Atelectasis: 0.8153
#   Cardiomegaly: 0.8850
#   Effusion: 0.8789
#   Infiltration: 0.7111
#   Mass: 0.8169
#   Nodule: 0.7538
#   Pneumonia: 0.7570
#   Pneumothorax: 0.8714
#   Consolidation: 0.7960
#   Edema: 0.8994
#   Emphysema: 0.8956
#   Fibrosis: 0.7793
#   Pleural_Thickening: 0.7925
#   Hernia: 0.8588
# Overall AUROC: 0.8193
#
# Epoch 4/7, Training Loss: 0.1728, Runtime: 159.20 seconds
# Model: densenet121, Epoch 4/7, Validation Loss: 0.1761
# Validation AUROC per class:
#   No Finding: 0.7847
#   Atelectasis: 0.8121
#   Cardiomegaly: 0.8875
#   Effusion: 0.8764
#   Infiltration: 0.7171
#   Mass: 0.8493
#   Nodule: 0.7534
#   Pneumonia: 0.7576
#   Pneumothorax: 0.8748
#   Consolidation: 0.7984
#   Edema: 0.8995
#   Emphysema: 0.9131
#   Fibrosis: 0.7958
#   Pleural_Thickening: 0.8141
#   Hernia: 0.8629
# Overall AUROC: 0.8264
#
# Epoch 5/7, Training Loss: 0.1699, Runtime: 159.49 seconds
# Model: densenet121, Epoch 5/7, Validation Loss: 0.1751
# Validation AUROC per class:
#   No Finding: 0.7847
#   Atelectasis: 0.8165
#   Cardiomegaly: 0.8887
#   Effusion: 0.8855
#   Infiltration: 0.7154
#   Mass: 0.8398
#   Nodule: 0.7524
#   Pneumonia: 0.7412
#   Pneumothorax: 0.8722
#   Consolidation: 0.8008
#   Edema: 0.8965
#   Emphysema: 0.9246
#   Fibrosis: 0.8142
#   Pleural_Thickening: 0.8161
#   Hernia: 0.8940
# Overall AUROC: 0.8295
#
# Epoch 6/7, Training Loss: 0.1669, Runtime: 159.69 seconds
# Model: densenet121, Epoch 6/7, Validation Loss: 0.1751
# Validation AUROC per class:
#   No Finding: 0.7816
#   Atelectasis: 0.8166
#   Cardiomegaly: 0.8894
#   Effusion: 0.8801
#   Infiltration: 0.7133
#   Mass: 0.8442
#   Nodule: 0.7584
#   Pneumonia: 0.7543
#   Pneumothorax: 0.8740
#   Consolidation: 0.7913
#   Edema: 0.8955
#   Emphysema: 0.9156
#   Fibrosis: 0.8066
#   Pleural_Thickening: 0.7951
#   Hernia: 0.8742
# Overall AUROC: 0.8260
#
# Epoch 7/7, Training Loss: 0.1645, Runtime: 159.39 seconds
# Model: densenet121, Epoch 7/7, Validation Loss: 0.1747
# Validation AUROC per class:
#   No Finding: 0.7864
#   Atelectasis: 0.8164
#   Cardiomegaly: 0.8888
#   Effusion: 0.8817
#   Infiltration: 0.7185
#   Mass: 0.8528
#   Nodule: 0.7665
#   Pneumonia: 0.7633
#   Pneumothorax: 0.8747
#   Consolidation: 0.8010
#   Edema: 0.8972
#   Emphysema: 0.9194
#   Fibrosis: 0.8084
#   Pleural_Thickening: 0.8199
#   Hernia: 0.8582
# Final AUROC: 0.8302
#
# Model saved to /student/csc490_project/shared/new_split_models/no_augment_densenet121_model.pth
# Epoch 1/7, Training Loss: 0.1896, Runtime: 1039.53 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 1/7, Validation Loss: 0.1789
# Validation AUROC per class:
#   No Finding: 0.7775
#   Atelectasis: 0.8005
#   Cardiomegaly: 0.8767
#   Effusion: 0.8726
#   Infiltration: 0.7045
#   Mass: 0.8388
#   Nodule: 0.7402
#   Pneumonia: 0.7381
#   Pneumothorax: 0.8701
#   Consolidation: 0.7956
#   Edema: 0.8916
#   Emphysema: 0.9064
#   Fibrosis: 0.7770
#   Pleural_Thickening: 0.7939
#   Hernia: 0.7365
# Overall AUROC: 0.8080
#
# Epoch 2/7, Training Loss: 0.1778, Runtime: 1039.54 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 2/7, Validation Loss: 0.1790
# Validation AUROC per class:
#   No Finding: 0.7832
#   Atelectasis: 0.8154
#   Cardiomegaly: 0.8905
#   Effusion: 0.8845
#   Infiltration: 0.7147
#   Mass: 0.8465
#   Nodule: 0.7612
#   Pneumonia: 0.7350
#   Pneumothorax: 0.8786
#   Consolidation: 0.7999
#   Edema: 0.8990
#   Emphysema: 0.9203
#   Fibrosis: 0.8060
#   Pleural_Thickening: 0.8094
#   Hernia: 0.8114
# Overall AUROC: 0.8237
#
# Epoch 3/7, Training Loss: 0.1732, Runtime: 1039.46 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 3/7, Validation Loss: 0.1737
# Validation AUROC per class:
#   No Finding: 0.7913
#   Atelectasis: 0.8269
#   Cardiomegaly: 0.8942
#   Effusion: 0.8868
#   Infiltration: 0.7165
#   Mass: 0.8482
#   Nodule: 0.7780
#   Pneumonia: 0.7342
#   Pneumothorax: 0.8903
#   Consolidation: 0.8037
#   Edema: 0.9008
#   Emphysema: 0.9275
#   Fibrosis: 0.8037
#   Pleural_Thickening: 0.8209
#   Hernia: 0.8522
# Overall AUROC: 0.8317
#
# Epoch 4/7, Training Loss: 0.1692, Runtime: 1039.45 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 4/7, Validation Loss: 0.1729
# Validation AUROC per class:
#   No Finding: 0.7898
#   Atelectasis: 0.8254
#   Cardiomegaly: 0.8983
#   Effusion: 0.8867
#   Infiltration: 0.7214
#   Mass: 0.8627
#   Nodule: 0.7697
#   Pneumonia: 0.7594
#   Pneumothorax: 0.8892
#   Consolidation: 0.8051
#   Edema: 0.9031
#   Emphysema: 0.9301
#   Fibrosis: 0.8170
#   Pleural_Thickening: 0.8244
#   Hernia: 0.8477
# Overall AUROC: 0.8353
#
# Epoch 5/7, Training Loss: 0.1653, Runtime: 1040.20 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 5/7, Validation Loss: 0.1721
# Validation AUROC per class:
#   No Finding: 0.7884
#   Atelectasis: 0.8268
#   Cardiomegaly: 0.9007
#   Effusion: 0.8850
#   Infiltration: 0.7138
#   Mass: 0.8573
#   Nodule: 0.7909
#   Pneumonia: 0.7520
#   Pneumothorax: 0.8851
#   Consolidation: 0.8048
#   Edema: 0.9015
#   Emphysema: 0.9313
#   Fibrosis: 0.8188
#   Pleural_Thickening: 0.8184
#   Hernia: 0.8631
# Overall AUROC: 0.8359
#
# Epoch 6/7, Training Loss: 0.1611, Runtime: 1040.16 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 6/7, Validation Loss: 0.1778
# Validation AUROC per class:
#   No Finding: 0.7806
#   Atelectasis: 0.8088
#   Cardiomegaly: 0.8989
#   Effusion: 0.8822
#   Infiltration: 0.7200
#   Mass: 0.8582
#   Nodule: 0.7721
#   Pneumonia: 0.7511
#   Pneumothorax: 0.8719
#   Consolidation: 0.7932
#   Edema: 0.9008
#   Emphysema: 0.9252
#   Fibrosis: 0.8109
#   Pleural_Thickening: 0.8141
#   Hernia: 0.8854
# Overall AUROC: 0.8316
#
# Epoch 7/7, Training Loss: 0.1561, Runtime: 1039.94 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 7/7, Validation Loss: 0.1769
# Validation AUROC per class:
#   No Finding: 0.7850
#   Atelectasis: 0.8160
#   Cardiomegaly: 0.8928
#   Effusion: 0.8818
#   Infiltration: 0.7187
#   Mass: 0.8590
#   Nodule: 0.7821
#   Pneumonia: 0.7393
#   Pneumothorax: 0.8827
#   Consolidation: 0.8037
#   Edema: 0.8990
#   Emphysema: 0.9266
#   Fibrosis: 0.8235
#   Pleural_Thickening: 0.7973
#   Hernia: 0.8885
# Final AUROC: 0.8331
#
# Model saved to /student/csc490_project/shared/new_split_models/no_augment_maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k_model.pth
# Epoch 1/7, Training Loss: 0.1923, Runtime: 975.51 seconds
# Model: swin_large_patch4_window7_224, Epoch 1/7, Validation Loss: 0.1813
# Validation AUROC per class:
#   No Finding: 0.7742
#   Atelectasis: 0.7928
#   Cardiomegaly: 0.8616
#   Effusion: 0.8674
#   Infiltration: 0.7005
#   Mass: 0.8108
#   Nodule: 0.7371
#   Pneumonia: 0.7433
#   Pneumothorax: 0.8457
#   Consolidation: 0.7900
#   Edema: 0.8799
#   Emphysema: 0.8692
#   Fibrosis: 0.7727
#   Pleural_Thickening: 0.7803
#   Hernia: 0.7059
# Overall AUROC: 0.7954
#
# Epoch 2/7, Training Loss: 0.1814, Runtime: 974.39 seconds
# Model: swin_large_patch4_window7_224, Epoch 2/7, Validation Loss: 0.1846
# Validation AUROC per class:
#   No Finding: 0.7765
#   Atelectasis: 0.8036
#   Cardiomegaly: 0.8924
#   Effusion: 0.8718
#   Infiltration: 0.7024
#   Mass: 0.8229
#   Nodule: 0.7340
#   Pneumonia: 0.7546
#   Pneumothorax: 0.8578
#   Consolidation: 0.7909
#   Edema: 0.8925
#   Emphysema: 0.8831
#   Fibrosis: 0.7592
#   Pleural_Thickening: 0.7918
#   Hernia: 0.7375
# Overall AUROC: 0.8047
#
# Epoch 3/7, Training Loss: 0.1773, Runtime: 973.99 seconds
# Model: swin_large_patch4_window7_224, Epoch 3/7, Validation Loss: 0.1763
# Validation AUROC per class:
#   No Finding: 0.7798
#   Atelectasis: 0.8114
#   Cardiomegaly: 0.8916
#   Effusion: 0.8797
#   Infiltration: 0.7122
#   Mass: 0.8422
#   Nodule: 0.7481
#   Pneumonia: 0.7377
#   Pneumothorax: 0.8715
#   Consolidation: 0.8014
#   Edema: 0.8925
#   Emphysema: 0.9153
#   Fibrosis: 0.7829
#   Pleural_Thickening: 0.8019
#   Hernia: 0.7944
# Overall AUROC: 0.8175
#
# Epoch 4/7, Training Loss: 0.1742, Runtime: 973.99 seconds
# Model: swin_large_patch4_window7_224, Epoch 4/7, Validation Loss: 0.1765
# Validation AUROC per class:
#   No Finding: 0.7817
#   Atelectasis: 0.8139
#   Cardiomegaly: 0.8998
#   Effusion: 0.8824
#   Infiltration: 0.7183
#   Mass: 0.8496
#   Nodule: 0.7615
#   Pneumonia: 0.7503
#   Pneumothorax: 0.8772
#   Consolidation: 0.8037
#   Edema: 0.8995
#   Emphysema: 0.9202
#   Fibrosis: 0.7965
#   Pleural_Thickening: 0.8006
#   Hernia: 0.8126
# Overall AUROC: 0.8245
#
# Epoch 5/7, Training Loss: 0.1710, Runtime: 973.62 seconds
# Model: swin_large_patch4_window7_224, Epoch 5/7, Validation Loss: 0.1739
# Validation AUROC per class:
#   No Finding: 0.7856
#   Atelectasis: 0.8182
#   Cardiomegaly: 0.8930
#   Effusion: 0.8843
#   Infiltration: 0.7219
#   Mass: 0.8409
#   Nodule: 0.7641
#   Pneumonia: 0.7593
#   Pneumothorax: 0.8848
#   Consolidation: 0.8051
#   Edema: 0.8988
#   Emphysema: 0.9169
#   Fibrosis: 0.8109
#   Pleural_Thickening: 0.8051
#   Hernia: 0.8386
# Overall AUROC: 0.8285
#
# Epoch 6/7, Training Loss: 0.1677, Runtime: 973.82 seconds
# Model: swin_large_patch4_window7_224, Epoch 6/7, Validation Loss: 0.1756
# Validation AUROC per class:
#   No Finding: 0.7860
#   Atelectasis: 0.8173
#   Cardiomegaly: 0.8848
#   Effusion: 0.8845
#   Infiltration: 0.7235
#   Mass: 0.8476
#   Nodule: 0.7596
#   Pneumonia: 0.7665
#   Pneumothorax: 0.8750
#   Consolidation: 0.8031
#   Edema: 0.9047
#   Emphysema: 0.9271
#   Fibrosis: 0.8132
#   Pleural_Thickening: 0.8039
#   Hernia: 0.8595
# Overall AUROC: 0.8304
#
# Epoch 7/7, Training Loss: 0.1645, Runtime: 973.94 seconds
# Model: swin_large_patch4_window7_224, Epoch 7/7, Validation Loss: 0.1749
# Validation AUROC per class:
#   No Finding: 0.7868
#   Atelectasis: 0.8141
#   Cardiomegaly: 0.8987
#   Effusion: 0.8838
#   Infiltration: 0.7200
#   Mass: 0.8456
#   Nodule: 0.7644
#   Pneumonia: 0.7680
#   Pneumothorax: 0.8735
#   Consolidation: 0.8016
#   Edema: 0.9028
#   Emphysema: 0.9205
#   Fibrosis: 0.8169
#   Pleural_Thickening: 0.8060
#   Hernia: 0.8452
# Final AUROC: 0.8299
#
# Model saved to /student/csc490_project/shared/new_split_models/no_augment_swin_large_patch4_window7_224_model.pth
# Epoch 1/7, Training Loss: 0.2012, Runtime: 549.55 seconds
# Model: vgg19.tv_in1k, Epoch 1/7, Validation Loss: 0.1931
# Validation AUROC per class:
#   No Finding: 0.7509
#   Atelectasis: 0.7542
#   Cardiomegaly: 0.7252
#   Effusion: 0.8596
#   Infiltration: 0.6680
#   Mass: 0.6925
#   Nodule: 0.6406
#   Pneumonia: 0.6959
#   Pneumothorax: 0.7843
#   Consolidation: 0.7695
#   Edema: 0.8400
#   Emphysema: 0.7212
#   Fibrosis: 0.6940
#   Pleural_Thickening: 0.7522
#   Hernia: 0.6480
# Overall AUROC: 0.7331
#
# Epoch 2/7, Training Loss: 0.1927, Runtime: 549.49 seconds
# Model: vgg19.tv_in1k, Epoch 2/7, Validation Loss: 0.1892
# Validation AUROC per class:
#   No Finding: 0.7647
#   Atelectasis: 0.7549
#   Cardiomegaly: 0.8255
#   Effusion: 0.8670
#   Infiltration: 0.6774
#   Mass: 0.7403
#   Nodule: 0.6823
#   Pneumonia: 0.6974
#   Pneumothorax: 0.8247
#   Consolidation: 0.7694
#   Edema: 0.8503
#   Emphysema: 0.7867
#   Fibrosis: 0.6920
#   Pleural_Thickening: 0.7497
#   Hernia: 0.6903
# Overall AUROC: 0.7582
#
# Epoch 3/7, Training Loss: 0.1882, Runtime: 549.31 seconds
# Model: vgg19.tv_in1k, Epoch 3/7, Validation Loss: 0.1860
# Validation AUROC per class:
#   No Finding: 0.7678
#   Atelectasis: 0.7753
#   Cardiomegaly: 0.8170
#   Effusion: 0.8708
#   Infiltration: 0.6787
#   Mass: 0.7913
#   Nodule: 0.7207
#   Pneumonia: 0.7038
#   Pneumothorax: 0.8188
#   Consolidation: 0.7794
#   Edema: 0.8644
#   Emphysema: 0.7939
#   Fibrosis: 0.7391
#   Pleural_Thickening: 0.7580
#   Hernia: 0.7536
# Overall AUROC: 0.7755
#
# Epoch 4/7, Training Loss: 0.1847, Runtime: 549.52 seconds
# Model: vgg19.tv_in1k, Epoch 4/7, Validation Loss: 0.1819
# Validation AUROC per class:
#   No Finding: 0.7742
#   Atelectasis: 0.7799
#   Cardiomegaly: 0.8576
#   Effusion: 0.8763
#   Infiltration: 0.6928
#   Mass: 0.8010
#   Nodule: 0.7290
#   Pneumonia: 0.7163
#   Pneumothorax: 0.8540
#   Consolidation: 0.7819
#   Edema: 0.8732
#   Emphysema: 0.8759
#   Fibrosis: 0.7575
#   Pleural_Thickening: 0.7708
#   Hernia: 0.7357
# Overall AUROC: 0.7917
#
# Epoch 5/7, Training Loss: 0.1819, Runtime: 549.88 seconds
# Model: vgg19.tv_in1k, Epoch 5/7, Validation Loss: 0.1824
# Validation AUROC per class:
#   No Finding: 0.7658
#   Atelectasis: 0.7791
#   Cardiomegaly: 0.8414
#   Effusion: 0.8734
#   Infiltration: 0.6823
#   Mass: 0.8194
#   Nodule: 0.7314
#   Pneumonia: 0.7147
#   Pneumothorax: 0.8481
#   Consolidation: 0.7727
#   Edema: 0.8644
#   Emphysema: 0.8691
#   Fibrosis: 0.7525
#   Pleural_Thickening: 0.7514
#   Hernia: 0.7095
# Overall AUROC: 0.7850
#
# Epoch 6/7, Training Loss: 0.1799, Runtime: 549.26 seconds
# Model: vgg19.tv_in1k, Epoch 6/7, Validation Loss: 0.1799
# Validation AUROC per class:
#   No Finding: 0.7778
#   Atelectasis: 0.7880
#   Cardiomegaly: 0.8593
#   Effusion: 0.8741
#   Infiltration: 0.6973
#   Mass: 0.8252
#   Nodule: 0.7354
#   Pneumonia: 0.7322
#   Pneumothorax: 0.8575
#   Consolidation: 0.7845
#   Edema: 0.8718
#   Emphysema: 0.8877
#   Fibrosis: 0.7642
#   Pleural_Thickening: 0.7810
#   Hernia: 0.7355
# Overall AUROC: 0.7981
#
# Epoch 7/7, Training Loss: 0.1781, Runtime: 549.34 seconds
# Model: vgg19.tv_in1k, Epoch 7/7, Validation Loss: 0.1774
# Validation AUROC per class:
#   No Finding: 0.7813
#   Atelectasis: 0.8001
#   Cardiomegaly: 0.8762
#   Effusion: 0.8791
#   Infiltration: 0.7037
#   Mass: 0.8335
#   Nodule: 0.7531
#   Pneumonia: 0.7244
#   Pneumothorax: 0.8623
#   Consolidation: 0.7872
#   Edema: 0.8677
#   Emphysema: 0.9011
#   Fibrosis: 0.7708
#   Pleural_Thickening: 0.7804
#   Hernia: 0.7393
# Final AUROC: 0.8040
#
# Model saved to /student/csc490_project/shared/new_split_models/no_augment_vgg19.tv_in1k_model.pth
