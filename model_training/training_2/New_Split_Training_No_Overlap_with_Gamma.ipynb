# %%
# Cell 1: Import required libraries
import os
import cv2
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision.transforms as transforms
import timm

from sklearn.metrics import roc_auc_score
from scipy.ndimage import gaussian_filter, map_coordinates
import random

import time

from sklearn.preprocessing import MultiLabelBinarizer

# %%
# Cell 2: Define custom augmentation transforms

# CLAHE Transform for grayscale images
class CLAHETransform:
    def __init__(self, clipLimit=2.0, tileGridSize=(8, 8)):
        self.clahe = cv2.createCLAHE(clipLimit=clipLimit, tileGridSize=tileGridSize)

    def __call__(self, img):
        img_np = np.array(img)
        # For grayscale images, apply CLAHE directly
        img_np = self.clahe.apply(img_np)
        return Image.fromarray(img_np)

# Gamma Correction Transform
class GammaCorrectionTransform:
    def __init__(self, gamma=1.0):
        self.gamma = gamma

    def __call__(self, img):
        img_np = np.array(img).astype(np.float32) / 255.0
        corrected = np.power(img_np, self.gamma)
        corrected = np.clip(corrected * 255, 0, 255).astype(np.uint8)
        return Image.fromarray(corrected)

# Elastic Deformation Transform
class ElasticTransform:
    def __init__(self, alpha=34, sigma=4, random_state=None):
        self.alpha = alpha
        self.sigma = sigma
        self.random_state = random_state if random_state is not None else np.random.RandomState(None)

    def __call__(self, img):
        img_np = np.array(img)
        shape = img_np.shape[:2]
        
        dx = gaussian_filter((self.random_state.rand(*shape) * 2 - 1), self.sigma, mode="constant", cval=0) * self.alpha
        dy = gaussian_filter((self.random_state.rand(*shape) * 2 - 1), self.sigma, mode="constant", cval=0) * self.alpha
        
        x, y = np.meshgrid(np.arange(shape[1]), np.arange(shape[0]))
        indices = np.reshape(y+dy, (-1, 1)), np.reshape(x+dx, (-1, 1))
        
        if img_np.ndim == 3:
            channels = []
            for i in range(img_np.shape[2]):
                channel = map_coordinates(img_np[..., i], indices, order=1, mode='reflect').reshape(shape)
                channels.append(channel)
            transformed = np.stack(channels, axis=2)
        else:
            transformed = map_coordinates(img_np, indices, order=1, mode='reflect').reshape(shape)
        return Image.fromarray(transformed.astype(np.uint8))

# %%
# Cell 3: Define Focal Loss for multi-label classification
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        """
        Args:
            alpha (float): Balancing factor.
            gamma (float): Focusing parameter.
            reduction (str): Reduction method ('mean', 'sum', or 'none').
        """
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        
    def forward(self, inputs, targets):
        # Compute binary cross entropy loss per element
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer

# Define the 15 classes (14 diseases plus "No Finding")
CLASSES = [
    "No Finding", "Atelectasis", "Cardiomegaly", "Effusion", "Infiltration", 
    "Mass", "Nodule", "Pneumonia", "Pneumothorax", "Consolidation", 
    "Edema", "Emphysema", "Fibrosis", "Pleural_Thickening", "Hernia"
]

# Load CSV data
df = pd.read_csv("/student/csc490_project/shared/labels.csv")

# Process the "Finding Labels" column.
# For "No Finding", this will return ["No Finding"],
# and for multiple findings it splits by '|'.
def process_labels(label_str):
    return label_str.split("|")

df["label_list"] = df["Finding Labels"].apply(process_labels)

# Initialize and apply MultiLabelBinarizer with our defined classes.
mlb = MultiLabelBinarizer(classes=CLASSES)
labels_array = mlb.fit_transform(df["label_list"])

# Save the multi-hot vectors into a new column.
df["labels"] = list(labels_array)

# Get the unique patient IDs from the dataset
unique_patients = df["Patient ID"].unique()

# Shuffle the patient IDs using a fixed random seed for reproducibility
np.random.seed(42)
np.random.shuffle(unique_patients)

# Determine the split index for a 70/30 split (by patient)
split_index = int(0.7 * len(unique_patients))
train_patients = unique_patients[:split_index]
val_patients = unique_patients[split_index:]

# Filter the dataframe based on the patient IDs for each split
train_df = df[df["Patient ID"].isin(train_patients)].reset_index(drop=True)
val_df = df[df["Patient ID"].isin(val_patients)].reset_index(drop=True)

print(f"Training samples: {len(train_df)}, Validation samples: {len(val_df)}")

# Print unique patient counts for each split to verify no overlap
print(f"Unique patients in training: {len(train_df['Patient ID'].unique())}")
print(f"Unique patients in validation: {len(val_df['Patient ID'].unique())}")

# Verify there is no overlap in patient IDs between the splits
overlap_ids = set(train_df["Patient ID"].unique()).intersection(val_df["Patient ID"].unique())
if overlap_ids:
    print("Overlap in Patient IDs found:", overlap_ids)
else:
    print("No overlap in Patient IDs between training and validation sets.")

# Define the dataset class using the precomputed multi-hot labels.
class ChestXrayDataset(Dataset):
    def __init__(self, df, root_dir, transform=None):
        """
        Args:
            df: DataFrame with columns "Image Index" and "labels".
            root_dir: Directory where images are stored.
            transform: Transformations to apply.
        """
        self.df = df
        self.root_dir = root_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        # Load the image in grayscale.
        img_name = os.path.join(self.root_dir, self.df.iloc[idx]["Image Index"])
        image = Image.open(img_name).convert("L")
        
        # Retrieve the multi-hot label vector (length 15).
        labels = np.array(self.df.iloc[idx]["labels"], dtype=np.float32)
        labels = torch.tensor(labels, dtype=torch.float)
        
        if self.transform:
            image = self.transform(image)
        return image, labels
# Out:
# Training samples: 78708, Validation samples: 33412
# Unique patients in training: 21563
# Unique patients in validation: 9242
# No overlap in Patient IDs between training and validation sets.

# %%
# Cell 5: Record split index

# Print dataset sizes
print(f"Total samples: {len(df)}")
print(f"Training samples: {len(train_df)}, Validation samples: {len(val_df)}")
print(f"Split index: {split_index}")

# Print first 5 indices of each split to verify consistency
print("First 5 indices in training set:")
print(train_df.index[:5].tolist())

print("First 5 indices in validation set:")
print(val_df.index[:5].tolist())

# Print first few image filenames in each split
print("First 5 images in training set:")
print(train_df["Image Index"].head().tolist())

print("First 5 images in validation set:")
print(val_df["Image Index"].head().tolist())
# Out:
# Total samples: 112120
# Training samples: 78708, Validation samples: 33412
# Split index: 21563
# First 5 indices in training set:
# [0, 1, 2, 3, 4]
# First 5 indices in validation set:
# [0, 1, 2, 3, 4]
# First 5 images in training set:
# ['00000001_000.png', '00000001_001.png', '00000001_002.png', '00000003_000.png', '00000003_001.png']
# First 5 images in validation set:
# ['00000002_000.png', '00000010_000.png', '00000012_000.png', '00000014_000.png', '00000017_000.png']

# %%
# Cell 6: Define data transforms with selectable augmentation

# Choose augmentation method: 'clahe', 'gamma', 'elastic', or 'none'
augmentation_method = 'gamma'  # Change this as needed

if augmentation_method == 'clahe':
    aug_transform = CLAHETransform(clipLimit=2.0, tileGridSize=(8, 8))
elif augmentation_method == 'gamma':
    aug_transform = GammaCorrectionTransform(gamma=0.8)  # adjust gamma value as needed
elif augmentation_method == 'elastic':
    aug_transform = ElasticTransform(alpha=34, sigma=4)
else:
    aug_transform = None

# Compose training transforms. The pipeline applies the selected augmentation,
# converts the grayscale image to 3 channels, and performs other random augmentations.
train_transforms_list = []
if aug_transform is not None:
    train_transforms_list.append(aug_transform)
    
train_transforms_list += [
    transforms.Grayscale(num_output_channels=3),  # Convert to 3 channels for the model
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
]

train_transform = transforms.Compose(train_transforms_list)

# Validation transforms: use deterministic preprocessing only
val_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Cell 7: Create DataLoaders for training and validation
train_dataset = ChestXrayDataset(train_df, root_dir="/student/csc490_project/shared/preprocessed_images/preprocessed_images", transform=train_transform)
val_dataset = ChestXrayDataset(val_df, root_dir="/student/csc490_project/shared/preprocessed_images/preprocessed_images", transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)

# %%
# Cell 8: Model List
model_names = ['coatnet_2_rw_224.sw_in12k_ft_in1k', 'convnext_large.fb_in22k', 'densenet121', 'maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k', 'swin_large_patch4_window7_224', 'vgg19.tv_in1k']
num_classes = 15

# %%
# Cell 9: Define the loss function selection
loss_type = 'bce'  # Change to 'focal' to use FocalLoss

if loss_type == 'bce':
    criterion = nn.BCEWithLogitsLoss()
elif loss_type == 'focal':
    criterion = FocalLoss(alpha=1, gamma=2, reduction='mean')
else:
    raise ValueError("Invalid loss_type. Choose 'bce' or 'focal'.")

# %%
# Cell 10: Training loop with validation AUROC evaluation
for model_name in model_names:
    
    model = timm.create_model(model_name, pretrained=True, num_classes=num_classes)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    if model_name == 'convnext_large.fb_in22k':
        num_epochs = 4
    else:
        num_epochs = 7

    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(num_epochs):
        start_time = time.time()
        model.train()
        running_loss = 0.0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * images.size(0)
        
        epoch_loss = running_loss / len(train_dataset)
        epoch_runtime = time.time() - start_time
        print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {epoch_loss:.4f}, Runtime: {epoch_runtime:.2f} seconds")
        
        # Validation evaluation
        model.eval()
        val_loss = 0.0
        all_preds = []
        all_labels = []
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                
                preds = torch.sigmoid(outputs).cpu().numpy()
                all_preds.append(preds)
                all_labels.append(labels.cpu().numpy())
        
        val_loss /= len(val_dataset)
        print(f"Model: {model_name}, Epoch {epoch+1}/{num_epochs}, Validation Loss: {val_loss:.4f}")
        
        all_preds = np.concatenate(all_preds, axis=0)
        all_labels = np.concatenate(all_labels, axis=0)
        
        # Compute AUROC for each class
        auroc_per_class = {}
        for i, class_name in enumerate(CLASSES):  # Iterate with class names directly
            try:
                auroc = roc_auc_score(all_labels[:, i], all_preds[:, i])
            except ValueError:
                auroc = float('nan')
            auroc_per_class[class_name] = auroc  # Store class name instead of index

        overall_auroc = np.nanmean(list(auroc_per_class.values()))

        print("Validation AUROC per class:")
        for class_name, score in auroc_per_class.items():
            print(f"  {class_name}: {score:.4f}")
        if epoch + 1 != num_epochs:
            print(f"Overall AUROC: {overall_auroc:.4f}\n")
        else:
            print(f"Final AUROC: {overall_auroc:.4f}\n")

    model_save_path = f"/student/csc490_project/shared/new_split_models/gamma_{model_name}_model.pth"
    torch.save(model.state_dict(), model_save_path)
    print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/7, Training Loss: 0.2048, Runtime: 651.55 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 1/7, Validation Loss: 0.1946
# Validation AUROC per class:
#   No Finding: 0.7565
#   Atelectasis: 0.7605
#   Cardiomegaly: 0.6488
#   Effusion: 0.8531
#   Infiltration: 0.6733
#   Mass: 0.6965
#   Nodule: 0.6713
#   Pneumonia: 0.6982
#   Pneumothorax: 0.7918
#   Consolidation: 0.7721
#   Edema: 0.8372
#   Emphysema: 0.7638
#   Fibrosis: 0.6861
#   Pleural_Thickening: 0.7363
#   Hernia: 0.6235
# Overall AUROC: 0.7313
#
# Epoch 2/7, Training Loss: 0.1935, Runtime: 651.08 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 2/7, Validation Loss: 0.1870
# Validation AUROC per class:
#   No Finding: 0.7648
#   Atelectasis: 0.7766
#   Cardiomegaly: 0.7152
#   Effusion: 0.8611
#   Infiltration: 0.6910
#   Mass: 0.7814
#   Nodule: 0.7223
#   Pneumonia: 0.7249
#   Pneumothorax: 0.8297
#   Consolidation: 0.7719
#   Edema: 0.8650
#   Emphysema: 0.8040
#   Fibrosis: 0.7237
#   Pleural_Thickening: 0.7449
#   Hernia: 0.7042
# Overall AUROC: 0.7654
#
# Epoch 3/7, Training Loss: 0.1877, Runtime: 651.31 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 3/7, Validation Loss: 0.1831
# Validation AUROC per class:
#   No Finding: 0.7712
#   Atelectasis: 0.7936
#   Cardiomegaly: 0.8372
#   Effusion: 0.8697
#   Infiltration: 0.6927
#   Mass: 0.7848
#   Nodule: 0.7216
#   Pneumonia: 0.7320
#   Pneumothorax: 0.8497
#   Consolidation: 0.7848
#   Edema: 0.8708
#   Emphysema: 0.8524
#   Fibrosis: 0.7310
#   Pleural_Thickening: 0.7630
#   Hernia: 0.7003
# Overall AUROC: 0.7837
#
# Epoch 4/7, Training Loss: 0.1835, Runtime: 651.16 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 4/7, Validation Loss: 0.1819
# Validation AUROC per class:
#   No Finding: 0.7758
#   Atelectasis: 0.8001
#   Cardiomegaly: 0.8475
#   Effusion: 0.8768
#   Infiltration: 0.6969
#   Mass: 0.8270
#   Nodule: 0.7352
#   Pneumonia: 0.7379
#   Pneumothorax: 0.8547
#   Consolidation: 0.7893
#   Edema: 0.8817
#   Emphysema: 0.8838
#   Fibrosis: 0.7620
#   Pleural_Thickening: 0.7803
#   Hernia: 0.7091
# Overall AUROC: 0.7972
#
# Epoch 5/7, Training Loss: 0.1806, Runtime: 651.39 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 5/7, Validation Loss: 0.1798
# Validation AUROC per class:
#   No Finding: 0.7793
#   Atelectasis: 0.8051
#   Cardiomegaly: 0.8513
#   Effusion: 0.8765
#   Infiltration: 0.6988
#   Mass: 0.8291
#   Nodule: 0.7577
#   Pneumonia: 0.7348
#   Pneumothorax: 0.8583
#   Consolidation: 0.7946
#   Edema: 0.8767
#   Emphysema: 0.8924
#   Fibrosis: 0.7621
#   Pleural_Thickening: 0.7888
#   Hernia: 0.7745
# Overall AUROC: 0.8053
#
# Epoch 6/7, Training Loss: 0.1782, Runtime: 651.78 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 6/7, Validation Loss: 0.1775
# Validation AUROC per class:
#   No Finding: 0.7832
#   Atelectasis: 0.8115
#   Cardiomegaly: 0.8794
#   Effusion: 0.8806
#   Infiltration: 0.7078
#   Mass: 0.8424
#   Nodule: 0.7574
#   Pneumonia: 0.7419
#   Pneumothorax: 0.8724
#   Consolidation: 0.7897
#   Edema: 0.8823
#   Emphysema: 0.9075
#   Fibrosis: 0.7736
#   Pleural_Thickening: 0.7897
#   Hernia: 0.7726
# Overall AUROC: 0.8128
#
# Epoch 7/7, Training Loss: 0.1765, Runtime: 651.24 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 7/7, Validation Loss: 0.1769
# Validation AUROC per class:
#   No Finding: 0.7836
#   Atelectasis: 0.8152
#   Cardiomegaly: 0.8743
#   Effusion: 0.8829
#   Infiltration: 0.7079
#   Mass: 0.8357
#   Nodule: 0.7624
#   Pneumonia: 0.7506
#   Pneumothorax: 0.8689
#   Consolidation: 0.7981
#   Edema: 0.8837
#   Emphysema: 0.8875
#   Fibrosis: 0.7640
#   Pleural_Thickening: 0.7982
#   Hernia: 0.7697
# Final AUROC: 0.8122
#
# Model saved to /student/csc490_project/shared/new_split_models/gamma_coatnet_2_rw_224.sw_in12k_ft_in1k_model.pth
# Epoch 1/4, Training Loss: 0.1853, Runtime: 1167.16 seconds
# Model: convnext_large.fb_in22k, Epoch 1/4, Validation Loss: 0.1758
# Validation AUROC per class:
#   No Finding: 0.7858
#   Atelectasis: 0.8063
#   Cardiomegaly: 0.9027
#   Effusion: 0.8820
#   Infiltration: 0.7096
#   Mass: 0.8502
#   Nodule: 0.7650
#   Pneumonia: 0.7504
#   Pneumothorax: 0.8839
#   Consolidation: 0.7936
#   Edema: 0.8958
#   Emphysema: 0.9073
#   Fibrosis: 0.7938
#   Pleural_Thickening: 0.8072
#   Hernia: 0.7883
# Overall AUROC: 0.8215
#
# Epoch 2/4, Training Loss: 0.1721, Runtime: 1167.50 seconds
# Model: convnext_large.fb_in22k, Epoch 2/4, Validation Loss: 0.1731
# Validation AUROC per class:
#   No Finding: 0.7896
#   Atelectasis: 0.8264
#   Cardiomegaly: 0.9051
#   Effusion: 0.8842
#   Infiltration: 0.7249
#   Mass: 0.8614
#   Nodule: 0.7875
#   Pneumonia: 0.7650
#   Pneumothorax: 0.8860
#   Consolidation: 0.8080
#   Edema: 0.9044
#   Emphysema: 0.9195
#   Fibrosis: 0.8106
#   Pleural_Thickening: 0.8103
#   Hernia: 0.8316
# Overall AUROC: 0.8343
#
# Epoch 3/4, Training Loss: 0.1640, Runtime: 1167.27 seconds
# Model: convnext_large.fb_in22k, Epoch 3/4, Validation Loss: 0.1743
# Validation AUROC per class:
#   No Finding: 0.7920
#   Atelectasis: 0.8258
#   Cardiomegaly: 0.9016
#   Effusion: 0.8842
#   Infiltration: 0.7269
#   Mass: 0.8606
#   Nodule: 0.7791
#   Pneumonia: 0.7590
#   Pneumothorax: 0.8873
#   Consolidation: 0.8074
#   Edema: 0.9033
#   Emphysema: 0.9198
#   Fibrosis: 0.8105
#   Pleural_Thickening: 0.8170
#   Hernia: 0.8746
# Overall AUROC: 0.8366
#
# Epoch 4/4, Training Loss: 0.1530, Runtime: 1167.16 seconds
# Model: convnext_large.fb_in22k, Epoch 4/4, Validation Loss: 0.1751
# Validation AUROC per class:
#   No Finding: 0.7876
#   Atelectasis: 0.8260
#   Cardiomegaly: 0.8899
#   Effusion: 0.8832
#   Infiltration: 0.7230
#   Mass: 0.8554
#   Nodule: 0.7759
#   Pneumonia: 0.7524
#   Pneumothorax: 0.8694
#   Consolidation: 0.8040
#   Edema: 0.8971
#   Emphysema: 0.9263
#   Fibrosis: 0.8139
#   Pleural_Thickening: 0.8127
#   Hernia: 0.8932
# Final AUROC: 0.8340
#
# Model saved to /student/csc490_project/shared/new_split_models/gamma_convnext_large.fb_in22k_model.pth
# Epoch 1/7, Training Loss: 0.1935, Runtime: 171.54 seconds
# Model: densenet121, Epoch 1/7, Validation Loss: 0.1813
# Validation AUROC per class:
#   No Finding: 0.7692
#   Atelectasis: 0.7963
#   Cardiomegaly: 0.8590
#   Effusion: 0.8709
#   Infiltration: 0.6846
#   Mass: 0.8083
#   Nodule: 0.7328
#   Pneumonia: 0.7261
#   Pneumothorax: 0.8591
#   Consolidation: 0.7870
#   Edema: 0.8851
#   Emphysema: 0.8862
#   Fibrosis: 0.7573
#   Pleural_Thickening: 0.7751
#   Hernia: 0.7293
# Overall AUROC: 0.7951
#
# Epoch 2/7, Training Loss: 0.1806, Runtime: 171.74 seconds
# Model: densenet121, Epoch 2/7, Validation Loss: 0.1775
# Validation AUROC per class:
#   No Finding: 0.7811
#   Atelectasis: 0.8076
#   Cardiomegaly: 0.8894
#   Effusion: 0.8801
#   Infiltration: 0.7026
#   Mass: 0.8331
#   Nodule: 0.7501
#   Pneumonia: 0.7346
#   Pneumothorax: 0.8695
#   Consolidation: 0.7919
#   Edema: 0.8886
#   Emphysema: 0.8992
#   Fibrosis: 0.7863
#   Pleural_Thickening: 0.8016
#   Hernia: 0.7996
# Overall AUROC: 0.8144
#
# Epoch 3/7, Training Loss: 0.1764, Runtime: 172.10 seconds
# Model: densenet121, Epoch 3/7, Validation Loss: 0.1762
# Validation AUROC per class:
#   No Finding: 0.7819
#   Atelectasis: 0.8122
#   Cardiomegaly: 0.8909
#   Effusion: 0.8820
#   Infiltration: 0.7119
#   Mass: 0.8262
#   Nodule: 0.7640
#   Pneumonia: 0.7526
#   Pneumothorax: 0.8710
#   Consolidation: 0.7833
#   Edema: 0.8963
#   Emphysema: 0.9116
#   Fibrosis: 0.7785
#   Pleural_Thickening: 0.7836
#   Hernia: 0.8179
# Overall AUROC: 0.8176
#
# Epoch 4/7, Training Loss: 0.1731, Runtime: 171.38 seconds
# Model: densenet121, Epoch 4/7, Validation Loss: 0.1749
# Validation AUROC per class:
#   No Finding: 0.7841
#   Atelectasis: 0.8132
#   Cardiomegaly: 0.8928
#   Effusion: 0.8839
#   Infiltration: 0.7089
#   Mass: 0.8573
#   Nodule: 0.7681
#   Pneumonia: 0.7438
#   Pneumothorax: 0.8675
#   Consolidation: 0.8020
#   Edema: 0.8989
#   Emphysema: 0.9179
#   Fibrosis: 0.7906
#   Pleural_Thickening: 0.8025
#   Hernia: 0.8200
# Overall AUROC: 0.8234
#
# Epoch 5/7, Training Loss: 0.1700, Runtime: 172.41 seconds
# Model: densenet121, Epoch 5/7, Validation Loss: 0.1745
# Validation AUROC per class:
#   No Finding: 0.7862
#   Atelectasis: 0.8202
#   Cardiomegaly: 0.8964
#   Effusion: 0.8809
#   Infiltration: 0.7156
#   Mass: 0.8466
#   Nodule: 0.7639
#   Pneumonia: 0.7436
#   Pneumothorax: 0.8769
#   Consolidation: 0.7963
#   Edema: 0.9015
#   Emphysema: 0.9188
#   Fibrosis: 0.8007
#   Pleural_Thickening: 0.8055
#   Hernia: 0.8490
# Overall AUROC: 0.8268
#
# Epoch 6/7, Training Loss: 0.1672, Runtime: 171.99 seconds
# Model: densenet121, Epoch 6/7, Validation Loss: 0.1773
# Validation AUROC per class:
#   No Finding: 0.7824
#   Atelectasis: 0.8161
#   Cardiomegaly: 0.8975
#   Effusion: 0.8821
#   Infiltration: 0.7117
#   Mass: 0.8478
#   Nodule: 0.7595
#   Pneumonia: 0.7173
#   Pneumothorax: 0.8736
#   Consolidation: 0.7915
#   Edema: 0.8991
#   Emphysema: 0.9143
#   Fibrosis: 0.8002
#   Pleural_Thickening: 0.8116
#   Hernia: 0.8542
# Overall AUROC: 0.8239
#
# Epoch 7/7, Training Loss: 0.1647, Runtime: 172.00 seconds
# Model: densenet121, Epoch 7/7, Validation Loss: 0.1753
# Validation AUROC per class:
#   No Finding: 0.7858
#   Atelectasis: 0.8196
#   Cardiomegaly: 0.8961
#   Effusion: 0.8836
#   Infiltration: 0.7131
#   Mass: 0.8531
#   Nodule: 0.7632
#   Pneumonia: 0.7677
#   Pneumothorax: 0.8733
#   Consolidation: 0.7983
#   Edema: 0.8990
#   Emphysema: 0.9181
#   Fibrosis: 0.7935
#   Pleural_Thickening: 0.8025
#   Hernia: 0.8551
# Final AUROC: 0.8281
#
# Model saved to /student/csc490_project/shared/new_split_models/gamma_densenet121_model.pth
# Epoch 1/7, Training Loss: 0.1901, Runtime: 1061.08 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 1/7, Validation Loss: 0.1815
# Validation AUROC per class:
#   No Finding: 0.7746
#   Atelectasis: 0.7990
#   Cardiomegaly: 0.8840
#   Effusion: 0.8683
#   Infiltration: 0.6995
#   Mass: 0.8289
#   Nodule: 0.7386
#   Pneumonia: 0.7309
#   Pneumothorax: 0.8644
#   Consolidation: 0.7849
#   Edema: 0.8889
#   Emphysema: 0.9068
#   Fibrosis: 0.7696
#   Pleural_Thickening: 0.7863
#   Hernia: 0.7476
# Overall AUROC: 0.8048
#
# Epoch 2/7, Training Loss: 0.1780, Runtime: 1060.96 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 2/7, Validation Loss: 0.1744
# Validation AUROC per class:
#   No Finding: 0.7857
#   Atelectasis: 0.8124
#   Cardiomegaly: 0.9038
#   Effusion: 0.8827
#   Infiltration: 0.7114
#   Mass: 0.8607
#   Nodule: 0.7664
#   Pneumonia: 0.7633
#   Pneumothorax: 0.8782
#   Consolidation: 0.8013
#   Edema: 0.9001
#   Emphysema: 0.9144
#   Fibrosis: 0.7928
#   Pleural_Thickening: 0.8009
#   Hernia: 0.8365
# Overall AUROC: 0.8274
#
# Epoch 3/7, Training Loss: 0.1732, Runtime: 1060.99 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 3/7, Validation Loss: 0.1756
# Validation AUROC per class:
#   No Finding: 0.7891
#   Atelectasis: 0.8234
#   Cardiomegaly: 0.9031
#   Effusion: 0.8847
#   Infiltration: 0.7192
#   Mass: 0.8550
#   Nodule: 0.7693
#   Pneumonia: 0.7547
#   Pneumothorax: 0.8723
#   Consolidation: 0.7961
#   Edema: 0.8998
#   Emphysema: 0.9158
#   Fibrosis: 0.7976
#   Pleural_Thickening: 0.8080
#   Hernia: 0.8551
# Overall AUROC: 0.8295
#
# Epoch 4/7, Training Loss: 0.1693, Runtime: 1061.31 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 4/7, Validation Loss: 0.1734
# Validation AUROC per class:
#   No Finding: 0.7927
#   Atelectasis: 0.8256
#   Cardiomegaly: 0.9100
#   Effusion: 0.8891
#   Infiltration: 0.7179
#   Mass: 0.8670
#   Nodule: 0.7797
#   Pneumonia: 0.7673
#   Pneumothorax: 0.8835
#   Consolidation: 0.8051
#   Edema: 0.9047
#   Emphysema: 0.9280
#   Fibrosis: 0.8067
#   Pleural_Thickening: 0.8195
#   Hernia: 0.8861
# Overall AUROC: 0.8388
#
# Epoch 5/7, Training Loss: 0.1656, Runtime: 1061.24 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 5/7, Validation Loss: 0.1736
# Validation AUROC per class:
#   No Finding: 0.7893
#   Atelectasis: 0.8186
#   Cardiomegaly: 0.9028
#   Effusion: 0.8817
#   Infiltration: 0.7217
#   Mass: 0.8618
#   Nodule: 0.7707
#   Pneumonia: 0.7469
#   Pneumothorax: 0.8794
#   Consolidation: 0.8096
#   Edema: 0.9038
#   Emphysema: 0.9229
#   Fibrosis: 0.8120
#   Pleural_Thickening: 0.8148
#   Hernia: 0.8871
# Overall AUROC: 0.8349
#
# Epoch 6/7, Training Loss: 0.1616, Runtime: 1061.08 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 6/7, Validation Loss: 0.1719
# Validation AUROC per class:
#   No Finding: 0.7911
#   Atelectasis: 0.8246
#   Cardiomegaly: 0.9100
#   Effusion: 0.8887
#   Infiltration: 0.7208
#   Mass: 0.8649
#   Nodule: 0.7791
#   Pneumonia: 0.7520
#   Pneumothorax: 0.8823
#   Consolidation: 0.8005
#   Edema: 0.9062
#   Emphysema: 0.9299
#   Fibrosis: 0.8024
#   Pleural_Thickening: 0.8244
#   Hernia: 0.8782
# Overall AUROC: 0.8370
#
# Epoch 7/7, Training Loss: 0.1571, Runtime: 1060.84 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 7/7, Validation Loss: 0.1787
# Validation AUROC per class:
#   No Finding: 0.7723
#   Atelectasis: 0.8123
#   Cardiomegaly: 0.9027
#   Effusion: 0.8800
#   Infiltration: 0.7123
#   Mass: 0.8487
#   Nodule: 0.7668
#   Pneumonia: 0.7313
#   Pneumothorax: 0.8703
#   Consolidation: 0.8016
#   Edema: 0.9035
#   Emphysema: 0.9158
#   Fibrosis: 0.8048
#   Pleural_Thickening: 0.7824
#   Hernia: 0.8803
# Final AUROC: 0.8257
#
# Model saved to /student/csc490_project/shared/new_split_models/gamma_maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k_model.pth
# Epoch 1/7, Training Loss: 0.1916, Runtime: 997.82 seconds
# Model: swin_large_patch4_window7_224, Epoch 1/7, Validation Loss: 0.1811
# Validation AUROC per class:
#   No Finding: 0.7726
#   Atelectasis: 0.8017
#   Cardiomegaly: 0.8804
#   Effusion: 0.8673
#   Infiltration: 0.7035
#   Mass: 0.8029
#   Nodule: 0.7428
#   Pneumonia: 0.7348
#   Pneumothorax: 0.8617
#   Consolidation: 0.7909
#   Edema: 0.8835
#   Emphysema: 0.8806
#   Fibrosis: 0.7658
#   Pleural_Thickening: 0.7899
#   Hernia: 0.7122
# Overall AUROC: 0.7994
#
# Epoch 2/7, Training Loss: 0.1808, Runtime: 996.71 seconds
# Model: swin_large_patch4_window7_224, Epoch 2/7, Validation Loss: 0.1777
# Validation AUROC per class:
#   No Finding: 0.7792
#   Atelectasis: 0.7979
#   Cardiomegaly: 0.8914
#   Effusion: 0.8760
#   Infiltration: 0.7059
#   Mass: 0.8382
#   Nodule: 0.7493
#   Pneumonia: 0.7293
#   Pneumothorax: 0.8714
#   Consolidation: 0.8020
#   Edema: 0.8864
#   Emphysema: 0.9129
#   Fibrosis: 0.7880
#   Pleural_Thickening: 0.7973
#   Hernia: 0.7554
# Overall AUROC: 0.8120
#
# Epoch 3/7, Training Loss: 0.1763, Runtime: 996.79 seconds
# Model: swin_large_patch4_window7_224, Epoch 3/7, Validation Loss: 0.1761
# Validation AUROC per class:
#   No Finding: 0.7838
#   Atelectasis: 0.8135
#   Cardiomegaly: 0.9000
#   Effusion: 0.8820
#   Infiltration: 0.7085
#   Mass: 0.8482
#   Nodule: 0.7534
#   Pneumonia: 0.7579
#   Pneumothorax: 0.8683
#   Consolidation: 0.8006
#   Edema: 0.8961
#   Emphysema: 0.9229
#   Fibrosis: 0.7831
#   Pleural_Thickening: 0.8081
#   Hernia: 0.8040
# Overall AUROC: 0.8220
#
# Epoch 4/7, Training Loss: 0.1730, Runtime: 996.63 seconds
# Model: swin_large_patch4_window7_224, Epoch 4/7, Validation Loss: 0.1760
# Validation AUROC per class:
#   No Finding: 0.7807
#   Atelectasis: 0.8109
#   Cardiomegaly: 0.8851
#   Effusion: 0.8825
#   Infiltration: 0.7140
#   Mass: 0.8318
#   Nodule: 0.7500
#   Pneumonia: 0.7460
#   Pneumothorax: 0.8787
#   Consolidation: 0.8026
#   Edema: 0.8968
#   Emphysema: 0.9211
#   Fibrosis: 0.7998
#   Pleural_Thickening: 0.8114
#   Hernia: 0.8206
# Overall AUROC: 0.8221
#
# Epoch 5/7, Training Loss: 0.1700, Runtime: 996.82 seconds
# Model: swin_large_patch4_window7_224, Epoch 5/7, Validation Loss: 0.1743
# Validation AUROC per class:
#   No Finding: 0.7842
#   Atelectasis: 0.8174
#   Cardiomegaly: 0.9042
#   Effusion: 0.8830
#   Infiltration: 0.7127
#   Mass: 0.8522
#   Nodule: 0.7666
#   Pneumonia: 0.7619
#   Pneumothorax: 0.8745
#   Consolidation: 0.8021
#   Edema: 0.8998
#   Emphysema: 0.9225
#   Fibrosis: 0.7994
#   Pleural_Thickening: 0.8141
#   Hernia: 0.8510
# Overall AUROC: 0.8297
#
# Epoch 6/7, Training Loss: 0.1668, Runtime: 996.34 seconds
# Model: swin_large_patch4_window7_224, Epoch 6/7, Validation Loss: 0.1755
# Validation AUROC per class:
#   No Finding: 0.7841
#   Atelectasis: 0.8160
#   Cardiomegaly: 0.9019
#   Effusion: 0.8814
#   Infiltration: 0.7093
#   Mass: 0.8476
#   Nodule: 0.7673
#   Pneumonia: 0.7412
#   Pneumothorax: 0.8882
#   Consolidation: 0.8029
#   Edema: 0.8919
#   Emphysema: 0.9294
#   Fibrosis: 0.8146
#   Pleural_Thickening: 0.8116
#   Hernia: 0.8551
# Overall AUROC: 0.8295
#
# Epoch 7/7, Training Loss: 0.1635, Runtime: 995.87 seconds
# Model: swin_large_patch4_window7_224, Epoch 7/7, Validation Loss: 0.1758
# Validation AUROC per class:
#   No Finding: 0.7818
#   Atelectasis: 0.8110
#   Cardiomegaly: 0.8981
#   Effusion: 0.8808
#   Infiltration: 0.7226
#   Mass: 0.8497
#   Nodule: 0.7524
#   Pneumonia: 0.7506
#   Pneumothorax: 0.8775
#   Consolidation: 0.7989
#   Edema: 0.8960
#   Emphysema: 0.9245
#   Fibrosis: 0.8043
#   Pleural_Thickening: 0.8208
#   Hernia: 0.8511
# Final AUROC: 0.8280
#
# Model saved to /student/csc490_project/shared/new_split_models/gamma_swin_large_patch4_window7_224_model.pth
# Epoch 1/7, Training Loss: 0.2019, Runtime: 558.20 seconds
# Model: vgg19.tv_in1k, Epoch 1/7, Validation Loss: 0.1919
# Validation AUROC per class:
#   No Finding: 0.7567
#   Atelectasis: 0.7562
#   Cardiomegaly: 0.6635
#   Effusion: 0.8597
#   Infiltration: 0.6786
#   Mass: 0.6831
#   Nodule: 0.6438
#   Pneumonia: 0.7062
#   Pneumothorax: 0.7951
#   Consolidation: 0.7697
#   Edema: 0.8598
#   Emphysema: 0.7357
#   Fibrosis: 0.6968
#   Pleural_Thickening: 0.7515
#   Hernia: 0.6329
# Overall AUROC: 0.7326
#
# Epoch 2/7, Training Loss: 0.1931, Runtime: 558.32 seconds
# Model: vgg19.tv_in1k, Epoch 2/7, Validation Loss: 0.1895
# Validation AUROC per class:
#   No Finding: 0.7631
#   Atelectasis: 0.7659
#   Cardiomegaly: 0.7684
#   Effusion: 0.8675
#   Infiltration: 0.6849
#   Mass: 0.7467
#   Nodule: 0.6724
#   Pneumonia: 0.7115
#   Pneumothorax: 0.8243
#   Consolidation: 0.7757
#   Edema: 0.8570
#   Emphysema: 0.7851
#   Fibrosis: 0.6931
#   Pleural_Thickening: 0.7585
#   Hernia: 0.6510
# Overall AUROC: 0.7550
#
# Epoch 3/7, Training Loss: 0.1879, Runtime: 558.01 seconds
# Model: vgg19.tv_in1k, Epoch 3/7, Validation Loss: 0.1845
# Validation AUROC per class:
#   No Finding: 0.7693
#   Atelectasis: 0.7762
#   Cardiomegaly: 0.8307
#   Effusion: 0.8716
#   Infiltration: 0.6935
#   Mass: 0.7784
#   Nodule: 0.7044
#   Pneumonia: 0.7210
#   Pneumothorax: 0.8403
#   Consolidation: 0.7828
#   Edema: 0.8798
#   Emphysema: 0.8231
#   Fibrosis: 0.7364
#   Pleural_Thickening: 0.7652
#   Hernia: 0.7168
# Overall AUROC: 0.7793
#
# Epoch 4/7, Training Loss: 0.1843, Runtime: 558.38 seconds
# Model: vgg19.tv_in1k, Epoch 4/7, Validation Loss: 0.1813
# Validation AUROC per class:
#   No Finding: 0.7766
#   Atelectasis: 0.7852
#   Cardiomegaly: 0.8486
#   Effusion: 0.8732
#   Infiltration: 0.6954
#   Mass: 0.8132
#   Nodule: 0.7262
#   Pneumonia: 0.7288
#   Pneumothorax: 0.8544
#   Consolidation: 0.7836
#   Edema: 0.8748
#   Emphysema: 0.8709
#   Fibrosis: 0.7508
#   Pleural_Thickening: 0.7636
#   Hernia: 0.7682
# Overall AUROC: 0.7942
#
# Epoch 5/7, Training Loss: 0.1819, Runtime: 557.87 seconds
# Model: vgg19.tv_in1k, Epoch 5/7, Validation Loss: 0.1806
# Validation AUROC per class:
#   No Finding: 0.7769
#   Atelectasis: 0.7884
#   Cardiomegaly: 0.8640
#   Effusion: 0.8765
#   Infiltration: 0.6903
#   Mass: 0.8167
#   Nodule: 0.7281
#   Pneumonia: 0.7301
#   Pneumothorax: 0.8656
#   Consolidation: 0.7841
#   Edema: 0.8792
#   Emphysema: 0.8968
#   Fibrosis: 0.7538
#   Pleural_Thickening: 0.7860
#   Hernia: 0.7583
# Overall AUROC: 0.7997
#
# Epoch 6/7, Training Loss: 0.1799, Runtime: 558.29 seconds
# Model: vgg19.tv_in1k, Epoch 6/7, Validation Loss: 0.1805
# Validation AUROC per class:
#   No Finding: 0.7774
#   Atelectasis: 0.7909
#   Cardiomegaly: 0.8700
#   Effusion: 0.8791
#   Infiltration: 0.6964
#   Mass: 0.8294
#   Nodule: 0.7323
#   Pneumonia: 0.7236
#   Pneumothorax: 0.8608
#   Consolidation: 0.7859
#   Edema: 0.8745
#   Emphysema: 0.9052
#   Fibrosis: 0.7592
#   Pleural_Thickening: 0.7814
#   Hernia: 0.7695
# Overall AUROC: 0.8024
#
# Epoch 7/7, Training Loss: 0.1778, Runtime: 558.23 seconds
# Model: vgg19.tv_in1k, Epoch 7/7, Validation Loss: 0.1827
# Validation AUROC per class:
#   No Finding: 0.7775
#   Atelectasis: 0.7859
#   Cardiomegaly: 0.8733
#   Effusion: 0.8761
#   Infiltration: 0.6984
#   Mass: 0.8196
#   Nodule: 0.7285
#   Pneumonia: 0.7296
#   Pneumothorax: 0.8730
#   Consolidation: 0.7857
#   Edema: 0.8803
#   Emphysema: 0.8927
#   Fibrosis: 0.7657
#   Pleural_Thickening: 0.7759
#   Hernia: 0.7696
# Final AUROC: 0.8021
#
# Model saved to /student/csc490_project/shared/new_split_models/gamma_vgg19.tv_in1k_model.pth
