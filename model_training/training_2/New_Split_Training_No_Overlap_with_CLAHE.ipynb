# %%
# Cell 1: Import required libraries
import os
import cv2
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision.transforms as transforms
import timm

from sklearn.metrics import roc_auc_score
from scipy.ndimage import gaussian_filter, map_coordinates
import random

import time

from sklearn.preprocessing import MultiLabelBinarizer

# %%
# Cell 2: Define custom augmentation transforms

# CLAHE Transform for grayscale images
class CLAHETransform:
    def __init__(self, clipLimit=2.0, tileGridSize=(8, 8)):
        self.clahe = cv2.createCLAHE(clipLimit=clipLimit, tileGridSize=tileGridSize)

    def __call__(self, img):
        img_np = np.array(img)
        # For grayscale images, apply CLAHE directly
        img_np = self.clahe.apply(img_np)
        return Image.fromarray(img_np)

# Gamma Correction Transform
class GammaCorrectionTransform:
    def __init__(self, gamma=1.0):
        self.gamma = gamma

    def __call__(self, img):
        img_np = np.array(img).astype(np.float32) / 255.0
        corrected = np.power(img_np, self.gamma)
        corrected = np.clip(corrected * 255, 0, 255).astype(np.uint8)
        return Image.fromarray(corrected)

# Elastic Deformation Transform
class ElasticTransform:
    def __init__(self, alpha=34, sigma=4, random_state=None):
        self.alpha = alpha
        self.sigma = sigma
        self.random_state = random_state if random_state is not None else np.random.RandomState(None)

    def __call__(self, img):
        img_np = np.array(img)
        shape = img_np.shape[:2]
        
        dx = gaussian_filter((self.random_state.rand(*shape) * 2 - 1), self.sigma, mode="constant", cval=0) * self.alpha
        dy = gaussian_filter((self.random_state.rand(*shape) * 2 - 1), self.sigma, mode="constant", cval=0) * self.alpha
        
        x, y = np.meshgrid(np.arange(shape[1]), np.arange(shape[0]))
        indices = np.reshape(y+dy, (-1, 1)), np.reshape(x+dx, (-1, 1))
        
        if img_np.ndim == 3:
            channels = []
            for i in range(img_np.shape[2]):
                channel = map_coordinates(img_np[..., i], indices, order=1, mode='reflect').reshape(shape)
                channels.append(channel)
            transformed = np.stack(channels, axis=2)
        else:
            transformed = map_coordinates(img_np, indices, order=1, mode='reflect').reshape(shape)
        return Image.fromarray(transformed.astype(np.uint8))

# %%
# Cell 3: Define Focal Loss for multi-label classification
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        """
        Args:
            alpha (float): Balancing factor.
            gamma (float): Focusing parameter.
            reduction (str): Reduction method ('mean', 'sum', or 'none').
        """
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        
    def forward(self, inputs, targets):
        # Compute binary cross entropy loss per element
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer

# Define the 15 classes (14 diseases plus "No Finding")
CLASSES = [
    "No Finding", "Atelectasis", "Cardiomegaly", "Effusion", "Infiltration", 
    "Mass", "Nodule", "Pneumonia", "Pneumothorax", "Consolidation", 
    "Edema", "Emphysema", "Fibrosis", "Pleural_Thickening", "Hernia"
]

# Load CSV data
df = pd.read_csv("/student/csc490_project/shared/labels.csv")

# Process the "Finding Labels" column.
# For "No Finding", this will return ["No Finding"],
# and for multiple findings it splits by '|'.
def process_labels(label_str):
    return label_str.split("|")

df["label_list"] = df["Finding Labels"].apply(process_labels)

# Initialize and apply MultiLabelBinarizer with our defined classes.
mlb = MultiLabelBinarizer(classes=CLASSES)
labels_array = mlb.fit_transform(df["label_list"])

# Save the multi-hot vectors into a new column.
df["labels"] = list(labels_array)

# Get the unique patient IDs from the dataset
unique_patients = df["Patient ID"].unique()

# Shuffle the patient IDs using a fixed random seed for reproducibility
np.random.seed(42)
np.random.shuffle(unique_patients)

# Determine the split index for a 70/30 split (by patient)
split_index = int(0.7 * len(unique_patients))
train_patients = unique_patients[:split_index]
val_patients = unique_patients[split_index:]

# Filter the dataframe based on the patient IDs for each split
train_df = df[df["Patient ID"].isin(train_patients)].reset_index(drop=True)
val_df = df[df["Patient ID"].isin(val_patients)].reset_index(drop=True)

print(f"Training samples: {len(train_df)}, Validation samples: {len(val_df)}")

# Print unique patient counts for each split to verify no overlap
print(f"Unique patients in training: {len(train_df['Patient ID'].unique())}")
print(f"Unique patients in validation: {len(val_df['Patient ID'].unique())}")

# Verify there is no overlap in patient IDs between the splits
overlap_ids = set(train_df["Patient ID"].unique()).intersection(val_df["Patient ID"].unique())
if overlap_ids:
    print("Overlap in Patient IDs found:", overlap_ids)
else:
    print("No overlap in Patient IDs between training and validation sets.")

# Define the dataset class using the precomputed multi-hot labels.
class ChestXrayDataset(Dataset):
    def __init__(self, df, root_dir, transform=None):
        """
        Args:
            df: DataFrame with columns "Image Index" and "labels".
            root_dir: Directory where images are stored.
            transform: Transformations to apply.
        """
        self.df = df
        self.root_dir = root_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        # Load the image in grayscale.
        img_name = os.path.join(self.root_dir, self.df.iloc[idx]["Image Index"])
        image = Image.open(img_name).convert("L")
        
        # Retrieve the multi-hot label vector (length 15).
        labels = np.array(self.df.iloc[idx]["labels"], dtype=np.float32)
        labels = torch.tensor(labels, dtype=torch.float)
        
        if self.transform:
            image = self.transform(image)
        return image, labels
# Out:
# Training samples: 78708, Validation samples: 33412
# Unique patients in training: 21563
# Unique patients in validation: 9242
# No overlap in Patient IDs between training and validation sets.

# %%
# Cell 5: Record split index

# Print dataset sizes
print(f"Total samples: {len(df)}")
print(f"Training samples: {len(train_df)}, Validation samples: {len(val_df)}")
print(f"Split index: {split_index}")

# Print first 5 indices of each split to verify consistency
print("First 5 indices in training set:")
print(train_df.index[:5].tolist())

print("First 5 indices in validation set:")
print(val_df.index[:5].tolist())

# Print first few image filenames in each split
print("First 5 images in training set:")
print(train_df["Image Index"].head().tolist())

print("First 5 images in validation set:")
print(val_df["Image Index"].head().tolist())
# Out:
# Total samples: 112120
# Training samples: 78708, Validation samples: 33412
# Split index: 21563
# First 5 indices in training set:
# [0, 1, 2, 3, 4]
# First 5 indices in validation set:
# [0, 1, 2, 3, 4]
# First 5 images in training set:
# ['00000001_000.png', '00000001_001.png', '00000001_002.png', '00000003_000.png', '00000003_001.png']
# First 5 images in validation set:
# ['00000002_000.png', '00000010_000.png', '00000012_000.png', '00000014_000.png', '00000017_000.png']

# %%
# Cell 6: Define data transforms with selectable augmentation

# Choose augmentation method: 'clahe', 'gamma', 'elastic', or 'none'
augmentation_method = 'clahe'  # Change this as needed

if augmentation_method == 'clahe':
    aug_transform = CLAHETransform(clipLimit=2.0, tileGridSize=(8, 8))
elif augmentation_method == 'gamma':
    aug_transform = GammaCorrectionTransform(gamma=0.8)  # adjust gamma value as needed
elif augmentation_method == 'elastic':
    aug_transform = ElasticTransform(alpha=34, sigma=4)
else:
    aug_transform = None

# Compose training transforms. The pipeline applies the selected augmentation,
# converts the grayscale image to 3 channels, and performs other random augmentations.
train_transforms_list = []
if aug_transform is not None:
    train_transforms_list.append(aug_transform)
    
train_transforms_list += [
    transforms.Grayscale(num_output_channels=3),  # Convert to 3 channels for the model
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
]

train_transform = transforms.Compose(train_transforms_list)

# Validation transforms: use deterministic preprocessing only
val_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Cell 7: Create DataLoaders for training and validation
train_dataset = ChestXrayDataset(train_df, root_dir="/student/csc490_project/shared/preprocessed_images/preprocessed_images", transform=train_transform)
val_dataset = ChestXrayDataset(val_df, root_dir="/student/csc490_project/shared/preprocessed_images/preprocessed_images", transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)

# %%
# Cell 8: Model List
model_names = ['coatnet_2_rw_224.sw_in12k_ft_in1k', 'convnext_large.fb_in22k', 'densenet121', 'maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k', 'swin_large_patch4_window7_224', 'vgg19.tv_in1k']
num_classes = 15

# %%
# Cell 9: Define the loss function selection
loss_type = 'bce'  # Change to 'focal' to use FocalLoss

if loss_type == 'bce':
    criterion = nn.BCEWithLogitsLoss()
elif loss_type == 'focal':
    criterion = FocalLoss(alpha=1, gamma=2, reduction='mean')
else:
    raise ValueError("Invalid loss_type. Choose 'bce' or 'focal'.")

# %%
# Cell 10: Training loop with validation AUROC evaluation
for model_name in model_names:
    
    model = timm.create_model(model_name, pretrained=True, num_classes=num_classes)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    if model_name == 'convnext_large.fb_in22k':
        num_epochs = 4
    else:
        num_epochs = 7

    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(num_epochs):
        start_time = time.time()
        model.train()
        running_loss = 0.0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * images.size(0)
        
        epoch_loss = running_loss / len(train_dataset)
        epoch_runtime = time.time() - start_time
        print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {epoch_loss:.4f}, Runtime: {epoch_runtime:.2f} seconds")
        
        # Validation evaluation
        model.eval()
        val_loss = 0.0
        all_preds = []
        all_labels = []
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                
                preds = torch.sigmoid(outputs).cpu().numpy()
                all_preds.append(preds)
                all_labels.append(labels.cpu().numpy())
        
        val_loss /= len(val_dataset)
        print(f"Model: {model_name}, Epoch {epoch+1}/{num_epochs}, Validation Loss: {val_loss:.4f}")
        
        all_preds = np.concatenate(all_preds, axis=0)
        all_labels = np.concatenate(all_labels, axis=0)
        
        # Compute AUROC for each class
        auroc_per_class = {}
        for i, class_name in enumerate(CLASSES):  # Iterate with class names directly
            try:
                auroc = roc_auc_score(all_labels[:, i], all_preds[:, i])
            except ValueError:
                auroc = float('nan')
            auroc_per_class[class_name] = auroc  # Store class name instead of index

        overall_auroc = np.nanmean(list(auroc_per_class.values()))

        print("Validation AUROC per class:")
        for class_name, score in auroc_per_class.items():
            print(f"  {class_name}: {score:.4f}")
        if epoch + 1 != num_epochs:
            print(f"Overall AUROC: {overall_auroc:.4f}\n")
        else:
            print(f"Final AUROC: {overall_auroc:.4f}\n")

    model_save_path = f"/student/csc490_project/shared/new_split_models_no_overlap/CLAHE_{model_name}_model.pth"
    torch.save(model.state_dict(), model_save_path)
    print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/7, Training Loss: 0.1970, Runtime: 642.10 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 1/7, Validation Loss: 0.1960
# Validation AUROC per class:
#   No Finding: 0.7539
#   Atelectasis: 0.7706
#   Cardiomegaly: 0.8278
#   Effusion: 0.8585
#   Infiltration: 0.6873
#   Mass: 0.7527
#   Nodule: 0.6880
#   Pneumonia: 0.7125
#   Pneumothorax: 0.8221
#   Consolidation: 0.7717
#   Edema: 0.8492
#   Emphysema: 0.7817
#   Fibrosis: 0.7114
#   Pleural_Thickening: 0.7380
#   Hernia: 0.6855
# Overall AUROC: 0.7607
#
# Epoch 2/7, Training Loss: 0.1857, Runtime: 642.24 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 2/7, Validation Loss: 0.1938
# Validation AUROC per class:
#   No Finding: 0.7557
#   Atelectasis: 0.7745
#   Cardiomegaly: 0.8624
#   Effusion: 0.8582
#   Infiltration: 0.6732
#   Mass: 0.7627
#   Nodule: 0.6699
#   Pneumonia: 0.6968
#   Pneumothorax: 0.8324
#   Consolidation: 0.7739
#   Edema: 0.8696
#   Emphysema: 0.8188
#   Fibrosis: 0.7380
#   Pleural_Thickening: 0.7444
#   Hernia: 0.7343
# Overall AUROC: 0.7710
#
# Epoch 3/7, Training Loss: 0.1809, Runtime: 642.02 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 3/7, Validation Loss: 0.1832
# Validation AUROC per class:
#   No Finding: 0.7692
#   Atelectasis: 0.7981
#   Cardiomegaly: 0.8425
#   Effusion: 0.8716
#   Infiltration: 0.6806
#   Mass: 0.8022
#   Nodule: 0.7357
#   Pneumonia: 0.7072
#   Pneumothorax: 0.8568
#   Consolidation: 0.7844
#   Edema: 0.8865
#   Emphysema: 0.8775
#   Fibrosis: 0.7600
#   Pleural_Thickening: 0.7729
#   Hernia: 0.7325
# Overall AUROC: 0.7919
#
# Epoch 4/7, Training Loss: 0.1782, Runtime: 642.42 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 4/7, Validation Loss: 0.1828
# Validation AUROC per class:
#   No Finding: 0.7684
#   Atelectasis: 0.7925
#   Cardiomegaly: 0.8650
#   Effusion: 0.8715
#   Infiltration: 0.6975
#   Mass: 0.8123
#   Nodule: 0.7289
#   Pneumonia: 0.7363
#   Pneumothorax: 0.8538
#   Consolidation: 0.7860
#   Edema: 0.8779
#   Emphysema: 0.8829
#   Fibrosis: 0.7658
#   Pleural_Thickening: 0.7902
#   Hernia: 0.7755
# Overall AUROC: 0.8003
#
# Epoch 5/7, Training Loss: 0.1757, Runtime: 642.32 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 5/7, Validation Loss: 0.1867
# Validation AUROC per class:
#   No Finding: 0.7676
#   Atelectasis: 0.7994
#   Cardiomegaly: 0.8557
#   Effusion: 0.8697
#   Infiltration: 0.6960
#   Mass: 0.8164
#   Nodule: 0.7275
#   Pneumonia: 0.7332
#   Pneumothorax: 0.8515
#   Consolidation: 0.7847
#   Edema: 0.8797
#   Emphysema: 0.8994
#   Fibrosis: 0.7668
#   Pleural_Thickening: 0.7854
#   Hernia: 0.7816
# Overall AUROC: 0.8010
#
# Epoch 6/7, Training Loss: 0.1734, Runtime: 642.34 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 6/7, Validation Loss: 0.1812
# Validation AUROC per class:
#   No Finding: 0.7744
#   Atelectasis: 0.7965
#   Cardiomegaly: 0.8861
#   Effusion: 0.8731
#   Infiltration: 0.7023
#   Mass: 0.8259
#   Nodule: 0.7412
#   Pneumonia: 0.7443
#   Pneumothorax: 0.8550
#   Consolidation: 0.7920
#   Edema: 0.8876
#   Emphysema: 0.8954
#   Fibrosis: 0.7664
#   Pleural_Thickening: 0.7946
#   Hernia: 0.8098
# Overall AUROC: 0.8096
#
# Epoch 7/7, Training Loss: 0.1716, Runtime: 642.23 seconds
# Model: coatnet_2_rw_224.sw_in12k_ft_in1k, Epoch 7/7, Validation Loss: 0.1836
# Validation AUROC per class:
#   No Finding: 0.7696
#   Atelectasis: 0.7961
#   Cardiomegaly: 0.8870
#   Effusion: 0.8720
#   Infiltration: 0.7030
#   Mass: 0.8163
#   Nodule: 0.7311
#   Pneumonia: 0.7166
#   Pneumothorax: 0.8588
#   Consolidation: 0.7890
#   Edema: 0.8874
#   Emphysema: 0.8944
#   Fibrosis: 0.7732
#   Pleural_Thickening: 0.7960
#   Hernia: 0.8607
# Final AUROC: 0.8101
#
# Model saved to /student/csc490_project/shared/new_split_models_no_overlap/CLAHE_coatnet_2_rw_224.sw_in12k_ft_in1k_model.pth
# Epoch 1/4, Training Loss: 0.1859, Runtime: 1137.12 seconds
# Model: convnext_large.fb_in22k, Epoch 1/4, Validation Loss: 0.1852
# Validation AUROC per class:
#   No Finding: 0.7804
#   Atelectasis: 0.8016
#   Cardiomegaly: 0.8704
#   Effusion: 0.8765
#   Infiltration: 0.7043
#   Mass: 0.8342
#   Nodule: 0.7547
#   Pneumonia: 0.7412
#   Pneumothorax: 0.8579
#   Consolidation: 0.7942
#   Edema: 0.8831
#   Emphysema: 0.8852
#   Fibrosis: 0.7440
#   Pleural_Thickening: 0.7881
#   Hernia: 0.7323
# Overall AUROC: 0.8032
#
# Epoch 2/4, Training Loss: 0.1725, Runtime: 1137.05 seconds
# Model: convnext_large.fb_in22k, Epoch 2/4, Validation Loss: 0.1777
# Validation AUROC per class:
#   No Finding: 0.7844
#   Atelectasis: 0.8183
#   Cardiomegaly: 0.8829
#   Effusion: 0.8813
#   Infiltration: 0.7117
#   Mass: 0.8485
#   Nodule: 0.7773
#   Pneumonia: 0.7290
#   Pneumothorax: 0.8760
#   Consolidation: 0.8011
#   Edema: 0.8975
#   Emphysema: 0.8998
#   Fibrosis: 0.7734
#   Pleural_Thickening: 0.8051
#   Hernia: 0.8762
# Overall AUROC: 0.8242
#
# Epoch 3/4, Training Loss: 0.1647, Runtime: 1137.49 seconds
# Model: convnext_large.fb_in22k, Epoch 3/4, Validation Loss: 0.1754
# Validation AUROC per class:
#   No Finding: 0.7883
#   Atelectasis: 0.8229
#   Cardiomegaly: 0.9071
#   Effusion: 0.8836
#   Infiltration: 0.7243
#   Mass: 0.8435
#   Nodule: 0.7816
#   Pneumonia: 0.7550
#   Pneumothorax: 0.8694
#   Consolidation: 0.8009
#   Edema: 0.8979
#   Emphysema: 0.9128
#   Fibrosis: 0.7958
#   Pleural_Thickening: 0.8044
#   Hernia: 0.8677
# Overall AUROC: 0.8303
#
# Epoch 4/4, Training Loss: 0.1536, Runtime: 1137.42 seconds
# Model: convnext_large.fb_in22k, Epoch 4/4, Validation Loss: 0.1849
# Validation AUROC per class:
#   No Finding: 0.7752
#   Atelectasis: 0.8062
#   Cardiomegaly: 0.8500
#   Effusion: 0.8757
#   Infiltration: 0.7059
#   Mass: 0.8396
#   Nodule: 0.7725
#   Pneumonia: 0.7460
#   Pneumothorax: 0.8407
#   Consolidation: 0.7898
#   Edema: 0.8932
#   Emphysema: 0.9021
#   Fibrosis: 0.7684
#   Pleural_Thickening: 0.8042
#   Hernia: 0.8824
# Final AUROC: 0.8168
#
# Model saved to /student/csc490_project/shared/new_split_models_no_overlap/CLAHE_convnext_large.fb_in22k_model.pth
# Epoch 1/7, Training Loss: 0.1930, Runtime: 171.69 seconds
# Model: densenet121, Epoch 1/7, Validation Loss: 0.1867
# Validation AUROC per class:
#   No Finding: 0.7633
#   Atelectasis: 0.7895
#   Cardiomegaly: 0.8525
#   Effusion: 0.8646
#   Infiltration: 0.6871
#   Mass: 0.7838
#   Nodule: 0.7207
#   Pneumonia: 0.7090
#   Pneumothorax: 0.8485
#   Consolidation: 0.7765
#   Edema: 0.8709
#   Emphysema: 0.8425
#   Fibrosis: 0.7705
#   Pleural_Thickening: 0.7797
#   Hernia: 0.8261
# Overall AUROC: 0.7923
#
# Epoch 2/7, Training Loss: 0.1802, Runtime: 170.70 seconds
# Model: densenet121, Epoch 2/7, Validation Loss: 0.1859
# Validation AUROC per class:
#   No Finding: 0.7700
#   Atelectasis: 0.7945
#   Cardiomegaly: 0.8447
#   Effusion: 0.8704
#   Infiltration: 0.7040
#   Mass: 0.8095
#   Nodule: 0.7354
#   Pneumonia: 0.7176
#   Pneumothorax: 0.8569
#   Consolidation: 0.7892
#   Edema: 0.8869
#   Emphysema: 0.8791
#   Fibrosis: 0.7647
#   Pleural_Thickening: 0.7883
#   Hernia: 0.8053
# Overall AUROC: 0.8011
#
# Epoch 3/7, Training Loss: 0.1759, Runtime: 171.83 seconds
# Model: densenet121, Epoch 3/7, Validation Loss: 0.1837
# Validation AUROC per class:
#   No Finding: 0.7773
#   Atelectasis: 0.8072
#   Cardiomegaly: 0.8757
#   Effusion: 0.8782
#   Infiltration: 0.7055
#   Mass: 0.8154
#   Nodule: 0.7343
#   Pneumonia: 0.7329
#   Pneumothorax: 0.8658
#   Consolidation: 0.7909
#   Edema: 0.8888
#   Emphysema: 0.8901
#   Fibrosis: 0.7659
#   Pleural_Thickening: 0.7989
#   Hernia: 0.8278
# Overall AUROC: 0.8103
#
# Epoch 4/7, Training Loss: 0.1724, Runtime: 170.48 seconds
# Model: densenet121, Epoch 4/7, Validation Loss: 0.1831
# Validation AUROC per class:
#   No Finding: 0.7740
#   Atelectasis: 0.8011
#   Cardiomegaly: 0.8817
#   Effusion: 0.8742
#   Infiltration: 0.7050
#   Mass: 0.8153
#   Nodule: 0.7386
#   Pneumonia: 0.7328
#   Pneumothorax: 0.8619
#   Consolidation: 0.7965
#   Edema: 0.8894
#   Emphysema: 0.8838
#   Fibrosis: 0.7671
#   Pleural_Thickening: 0.7974
#   Hernia: 0.8459
# Overall AUROC: 0.8110
#
# Epoch 5/7, Training Loss: 0.1694, Runtime: 171.59 seconds
# Model: densenet121, Epoch 5/7, Validation Loss: 0.1797
# Validation AUROC per class:
#   No Finding: 0.7749
#   Atelectasis: 0.8056
#   Cardiomegaly: 0.8670
#   Effusion: 0.8766
#   Infiltration: 0.7021
#   Mass: 0.8246
#   Nodule: 0.7581
#   Pneumonia: 0.7353
#   Pneumothorax: 0.8451
#   Consolidation: 0.7960
#   Edema: 0.8897
#   Emphysema: 0.8878
#   Fibrosis: 0.7784
#   Pleural_Thickening: 0.7953
#   Hernia: 0.8535
# Overall AUROC: 0.8127
#
# Epoch 6/7, Training Loss: 0.1667, Runtime: 171.29 seconds
# Model: densenet121, Epoch 6/7, Validation Loss: 0.1835
# Validation AUROC per class:
#   No Finding: 0.7735
#   Atelectasis: 0.8022
#   Cardiomegaly: 0.8612
#   Effusion: 0.8735
#   Infiltration: 0.7053
#   Mass: 0.8268
#   Nodule: 0.7542
#   Pneumonia: 0.7251
#   Pneumothorax: 0.8550
#   Consolidation: 0.7795
#   Edema: 0.8839
#   Emphysema: 0.8955
#   Fibrosis: 0.7795
#   Pleural_Thickening: 0.8005
#   Hernia: 0.8588
# Overall AUROC: 0.8116
#
# Epoch 7/7, Training Loss: 0.1638, Runtime: 171.44 seconds
# Model: densenet121, Epoch 7/7, Validation Loss: 0.1913
# Validation AUROC per class:
#   No Finding: 0.7602
#   Atelectasis: 0.7975
#   Cardiomegaly: 0.8464
#   Effusion: 0.8605
#   Infiltration: 0.7004
#   Mass: 0.8066
#   Nodule: 0.7298
#   Pneumonia: 0.7290
#   Pneumothorax: 0.8389
#   Consolidation: 0.7793
#   Edema: 0.8734
#   Emphysema: 0.8681
#   Fibrosis: 0.7815
#   Pleural_Thickening: 0.7798
#   Hernia: 0.8454
# Final AUROC: 0.7998
#
# Model saved to /student/csc490_project/shared/new_split_models_no_overlap/CLAHE_densenet121_model.pth
# Epoch 1/7, Training Loss: 0.1894, Runtime: 1039.08 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 1/7, Validation Loss: 0.1890
# Validation AUROC per class:
#   No Finding: 0.7703
#   Atelectasis: 0.8040
#   Cardiomegaly: 0.8814
#   Effusion: 0.8693
#   Infiltration: 0.6847
#   Mass: 0.8031
#   Nodule: 0.7395
#   Pneumonia: 0.7240
#   Pneumothorax: 0.8530
#   Consolidation: 0.7771
#   Edema: 0.8682
#   Emphysema: 0.8625
#   Fibrosis: 0.7290
#   Pleural_Thickening: 0.7718
#   Hernia: 0.7486
# Overall AUROC: 0.7924
#
# Epoch 2/7, Training Loss: 0.1779, Runtime: 1038.41 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 2/7, Validation Loss: 0.1808
# Validation AUROC per class:
#   No Finding: 0.7776
#   Atelectasis: 0.8094
#   Cardiomegaly: 0.8700
#   Effusion: 0.8779
#   Infiltration: 0.7068
#   Mass: 0.8315
#   Nodule: 0.7567
#   Pneumonia: 0.7245
#   Pneumothorax: 0.8712
#   Consolidation: 0.7914
#   Edema: 0.8828
#   Emphysema: 0.9139
#   Fibrosis: 0.7733
#   Pleural_Thickening: 0.7993
#   Hernia: 0.7780
# Overall AUROC: 0.8110
#
# Epoch 3/7, Training Loss: 0.1730, Runtime: 1038.20 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 3/7, Validation Loss: 0.1822
# Validation AUROC per class:
#   No Finding: 0.7820
#   Atelectasis: 0.8025
#   Cardiomegaly: 0.9003
#   Effusion: 0.8784
#   Infiltration: 0.7104
#   Mass: 0.8303
#   Nodule: 0.7550
#   Pneumonia: 0.7306
#   Pneumothorax: 0.8781
#   Consolidation: 0.7959
#   Edema: 0.8964
#   Emphysema: 0.9135
#   Fibrosis: 0.7907
#   Pleural_Thickening: 0.8047
#   Hernia: 0.8590
# Overall AUROC: 0.8218
#
# Epoch 4/7, Training Loss: 0.1690, Runtime: 1038.14 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 4/7, Validation Loss: 0.1828
# Validation AUROC per class:
#   No Finding: 0.7742
#   Atelectasis: 0.8081
#   Cardiomegaly: 0.8965
#   Effusion: 0.8672
#   Infiltration: 0.7034
#   Mass: 0.8454
#   Nodule: 0.7680
#   Pneumonia: 0.7382
#   Pneumothorax: 0.8726
#   Consolidation: 0.7924
#   Edema: 0.8743
#   Emphysema: 0.9159
#   Fibrosis: 0.7990
#   Pleural_Thickening: 0.7998
#   Hernia: 0.8407
# Overall AUROC: 0.8197
#
# Epoch 5/7, Training Loss: 0.1651, Runtime: 1038.37 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 5/7, Validation Loss: 0.1799
# Validation AUROC per class:
#   No Finding: 0.7845
#   Atelectasis: 0.8203
#   Cardiomegaly: 0.8863
#   Effusion: 0.8825
#   Infiltration: 0.7146
#   Mass: 0.8470
#   Nodule: 0.7579
#   Pneumonia: 0.7525
#   Pneumothorax: 0.8712
#   Consolidation: 0.7932
#   Edema: 0.8980
#   Emphysema: 0.9205
#   Fibrosis: 0.7897
#   Pleural_Thickening: 0.8056
#   Hernia: 0.8827
# Overall AUROC: 0.8271
#
# Epoch 6/7, Training Loss: 0.1607, Runtime: 1038.09 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 6/7, Validation Loss: 0.1778
# Validation AUROC per class:
#   No Finding: 0.7813
#   Atelectasis: 0.8146
#   Cardiomegaly: 0.8964
#   Effusion: 0.8777
#   Infiltration: 0.7182
#   Mass: 0.8458
#   Nodule: 0.7565
#   Pneumonia: 0.7491
#   Pneumothorax: 0.8604
#   Consolidation: 0.8021
#   Edema: 0.8912
#   Emphysema: 0.9125
#   Fibrosis: 0.8099
#   Pleural_Thickening: 0.7979
#   Hernia: 0.8505
# Overall AUROC: 0.8243
#
# Epoch 7/7, Training Loss: 0.1559, Runtime: 1038.14 seconds
# Model: maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k, Epoch 7/7, Validation Loss: 0.1816
# Validation AUROC per class:
#   No Finding: 0.7808
#   Atelectasis: 0.8152
#   Cardiomegaly: 0.8785
#   Effusion: 0.8775
#   Infiltration: 0.7087
#   Mass: 0.8469
#   Nodule: 0.7725
#   Pneumonia: 0.7449
#   Pneumothorax: 0.8670
#   Consolidation: 0.7969
#   Edema: 0.8953
#   Emphysema: 0.9088
#   Fibrosis: 0.8061
#   Pleural_Thickening: 0.7997
#   Hernia: 0.8509
# Final AUROC: 0.8233
#
# Model saved to /student/csc490_project/shared/new_split_models_no_overlap/CLAHE_maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k_model.pth
# Epoch 1/7, Training Loss: 0.1912, Runtime: 973.80 seconds
# Model: swin_large_patch4_window7_224, Epoch 1/7, Validation Loss: 0.1813
# Validation AUROC per class:
#   No Finding: 0.7736
#   Atelectasis: 0.7913
#   Cardiomegaly: 0.8625
#   Effusion: 0.8695
#   Infiltration: 0.7021
#   Mass: 0.8151
#   Nodule: 0.7348
#   Pneumonia: 0.7356
#   Pneumothorax: 0.8657
#   Consolidation: 0.7902
#   Edema: 0.8893
#   Emphysema: 0.8618
#   Fibrosis: 0.7529
#   Pleural_Thickening: 0.7741
#   Hernia: 0.6947
# Overall AUROC: 0.7942
#
# Epoch 2/7, Training Loss: 0.1804, Runtime: 973.87 seconds
# Model: swin_large_patch4_window7_224, Epoch 2/7, Validation Loss: 0.1807
# Validation AUROC per class:
#   No Finding: 0.7767
#   Atelectasis: 0.7956
#   Cardiomegaly: 0.8781
#   Effusion: 0.8718
#   Infiltration: 0.7069
#   Mass: 0.8248
#   Nodule: 0.7455
#   Pneumonia: 0.7270
#   Pneumothorax: 0.8670
#   Consolidation: 0.7928
#   Edema: 0.8928
#   Emphysema: 0.8980
#   Fibrosis: 0.7534
#   Pleural_Thickening: 0.7786
#   Hernia: 0.7509
# Overall AUROC: 0.8040
#
# Epoch 3/7, Training Loss: 0.1761, Runtime: 973.85 seconds
# Model: swin_large_patch4_window7_224, Epoch 3/7, Validation Loss: 0.1777
# Validation AUROC per class:
#   No Finding: 0.7772
#   Atelectasis: 0.8027
#   Cardiomegaly: 0.8819
#   Effusion: 0.8746
#   Infiltration: 0.7066
#   Mass: 0.8158
#   Nodule: 0.7546
#   Pneumonia: 0.7352
#   Pneumothorax: 0.8739
#   Consolidation: 0.7925
#   Edema: 0.8911
#   Emphysema: 0.9129
#   Fibrosis: 0.7844
#   Pleural_Thickening: 0.7980
#   Hernia: 0.8073
# Overall AUROC: 0.8139
#
# Epoch 4/7, Training Loss: 0.1727, Runtime: 973.83 seconds
# Model: swin_large_patch4_window7_224, Epoch 4/7, Validation Loss: 0.1786
# Validation AUROC per class:
#   No Finding: 0.7768
#   Atelectasis: 0.8033
#   Cardiomegaly: 0.8930
#   Effusion: 0.8745
#   Infiltration: 0.7087
#   Mass: 0.8216
#   Nodule: 0.7349
#   Pneumonia: 0.7435
#   Pneumothorax: 0.8745
#   Consolidation: 0.7912
#   Edema: 0.8926
#   Emphysema: 0.9116
#   Fibrosis: 0.7987
#   Pleural_Thickening: 0.8023
#   Hernia: 0.7758
# Overall AUROC: 0.8135
#
# Epoch 5/7, Training Loss: 0.1694, Runtime: 973.94 seconds
# Model: swin_large_patch4_window7_224, Epoch 5/7, Validation Loss: 0.1801
# Validation AUROC per class:
#   No Finding: 0.7783
#   Atelectasis: 0.8042
#   Cardiomegaly: 0.8910
#   Effusion: 0.8725
#   Infiltration: 0.7054
#   Mass: 0.8234
#   Nodule: 0.7385
#   Pneumonia: 0.7354
#   Pneumothorax: 0.8629
#   Consolidation: 0.7935
#   Edema: 0.8925
#   Emphysema: 0.8980
#   Fibrosis: 0.7949
#   Pleural_Thickening: 0.8045
#   Hernia: 0.8272
# Overall AUROC: 0.8148
#
# Epoch 6/7, Training Loss: 0.1661, Runtime: 973.44 seconds
# Model: swin_large_patch4_window7_224, Epoch 6/7, Validation Loss: 0.1787
# Validation AUROC per class:
#   No Finding: 0.7766
#   Atelectasis: 0.8031
#   Cardiomegaly: 0.8933
#   Effusion: 0.8754
#   Infiltration: 0.7130
#   Mass: 0.8282
#   Nodule: 0.7435
#   Pneumonia: 0.7496
#   Pneumothorax: 0.8696
#   Consolidation: 0.7920
#   Edema: 0.8961
#   Emphysema: 0.9091
#   Fibrosis: 0.7682
#   Pleural_Thickening: 0.8036
#   Hernia: 0.8465
# Overall AUROC: 0.8178
#
# Epoch 7/7, Training Loss: 0.1624, Runtime: 972.69 seconds
# Model: swin_large_patch4_window7_224, Epoch 7/7, Validation Loss: 0.1852
# Validation AUROC per class:
#   No Finding: 0.7803
#   Atelectasis: 0.8074
#   Cardiomegaly: 0.8885
#   Effusion: 0.8721
#   Infiltration: 0.7221
#   Mass: 0.8327
#   Nodule: 0.7472
#   Pneumonia: 0.7430
#   Pneumothorax: 0.8644
#   Consolidation: 0.7930
#   Edema: 0.8953
#   Emphysema: 0.9143
#   Fibrosis: 0.7813
#   Pleural_Thickening: 0.7971
#   Hernia: 0.8577
# Final AUROC: 0.8197
#
# Model saved to /student/csc490_project/shared/new_split_models_no_overlap/CLAHE_swin_large_patch4_window7_224_model.pth
# Epoch 1/7, Training Loss: 0.2012, Runtime: 549.76 seconds
# Model: vgg19.tv_in1k, Epoch 1/7, Validation Loss: 0.1972
# Validation AUROC per class:
#   No Finding: 0.7469
#   Atelectasis: 0.7436
#   Cardiomegaly: 0.6911
#   Effusion: 0.8525
#   Infiltration: 0.6707
#   Mass: 0.6701
#   Nodule: 0.5882
#   Pneumonia: 0.6919
#   Pneumothorax: 0.7778
#   Consolidation: 0.7632
#   Edema: 0.8378
#   Emphysema: 0.7168
#   Fibrosis: 0.6931
#   Pleural_Thickening: 0.7126
#   Hernia: 0.6235
# Overall AUROC: 0.7186
#
# Epoch 2/7, Training Loss: 0.1931, Runtime: 549.93 seconds
# Model: vgg19.tv_in1k, Epoch 2/7, Validation Loss: 0.1913
# Validation AUROC per class:
#   No Finding: 0.7551
#   Atelectasis: 0.7545
#   Cardiomegaly: 0.8217
#   Effusion: 0.8645
#   Infiltration: 0.6788
#   Mass: 0.7112
#   Nodule: 0.6643
#   Pneumonia: 0.7024
#   Pneumothorax: 0.8163
#   Consolidation: 0.7762
#   Edema: 0.8420
#   Emphysema: 0.7818
#   Fibrosis: 0.7180
#   Pleural_Thickening: 0.7473
#   Hernia: 0.6764
# Overall AUROC: 0.7540
#
# Epoch 3/7, Training Loss: 0.1879, Runtime: 550.01 seconds
# Model: vgg19.tv_in1k, Epoch 3/7, Validation Loss: 0.1899
# Validation AUROC per class:
#   No Finding: 0.7613
#   Atelectasis: 0.7670
#   Cardiomegaly: 0.8303
#   Effusion: 0.8643
#   Infiltration: 0.6814
#   Mass: 0.7474
#   Nodule: 0.7055
#   Pneumonia: 0.7007
#   Pneumothorax: 0.8234
#   Consolidation: 0.7681
#   Edema: 0.8542
#   Emphysema: 0.7897
#   Fibrosis: 0.7164
#   Pleural_Thickening: 0.7377
#   Hernia: 0.7071
# Overall AUROC: 0.7636
#
# Epoch 4/7, Training Loss: 0.1846, Runtime: 549.37 seconds
# Model: vgg19.tv_in1k, Epoch 4/7, Validation Loss: 0.1856
# Validation AUROC per class:
#   No Finding: 0.7677
#   Atelectasis: 0.7706
#   Cardiomegaly: 0.8479
#   Effusion: 0.8665
#   Infiltration: 0.6865
#   Mass: 0.7899
#   Nodule: 0.7230
#   Pneumonia: 0.7113
#   Pneumothorax: 0.8406
#   Consolidation: 0.7745
#   Edema: 0.8691
#   Emphysema: 0.8473
#   Fibrosis: 0.7368
#   Pleural_Thickening: 0.7425
#   Hernia: 0.7268
# Overall AUROC: 0.7801
#
# Epoch 5/7, Training Loss: 0.1822, Runtime: 549.77 seconds
# Model: vgg19.tv_in1k, Epoch 5/7, Validation Loss: 0.1881
# Validation AUROC per class:
#   No Finding: 0.7679
#   Atelectasis: 0.7774
#   Cardiomegaly: 0.8729
#   Effusion: 0.8691
#   Infiltration: 0.6889
#   Mass: 0.7904
#   Nodule: 0.7051
#   Pneumonia: 0.7243
#   Pneumothorax: 0.8421
#   Consolidation: 0.7799
#   Edema: 0.8682
#   Emphysema: 0.8481
#   Fibrosis: 0.7351
#   Pleural_Thickening: 0.7640
#   Hernia: 0.7118
# Overall AUROC: 0.7830
#
# Epoch 6/7, Training Loss: 0.1803, Runtime: 550.27 seconds
# Model: vgg19.tv_in1k, Epoch 6/7, Validation Loss: 0.1836
# Validation AUROC per class:
#   No Finding: 0.7717
#   Atelectasis: 0.7890
#   Cardiomegaly: 0.8732
#   Effusion: 0.8728
#   Infiltration: 0.6916
#   Mass: 0.7974
#   Nodule: 0.7242
#   Pneumonia: 0.7201
#   Pneumothorax: 0.8555
#   Consolidation: 0.7793
#   Edema: 0.8736
#   Emphysema: 0.8780
#   Fibrosis: 0.7405
#   Pleural_Thickening: 0.7683
#   Hernia: 0.7249
# Overall AUROC: 0.7907
#
# Epoch 7/7, Training Loss: 0.1784, Runtime: 549.49 seconds
# Model: vgg19.tv_in1k, Epoch 7/7, Validation Loss: 0.1909
# Validation AUROC per class:
#   No Finding: 0.7676
#   Atelectasis: 0.7770
#   Cardiomegaly: 0.8678
#   Effusion: 0.8669
#   Infiltration: 0.6870
#   Mass: 0.8051
#   Nodule: 0.7227
#   Pneumonia: 0.7215
#   Pneumothorax: 0.8448
#   Consolidation: 0.7730
#   Edema: 0.8752
#   Emphysema: 0.8684
#   Fibrosis: 0.7397
#   Pleural_Thickening: 0.7642
#   Hernia: 0.7616
# Final AUROC: 0.7895
#
# Model saved to /student/csc490_project/shared/new_split_models_no_overlap/CLAHE_vgg19.tv_in1k_model.pth
